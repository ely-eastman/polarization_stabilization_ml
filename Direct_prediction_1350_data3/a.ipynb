# %%
import os
data_path = "../Data/data_angles/data3_angles.csv"
print("Attempting to access:", data_path)
print("Full path:", os.path.abspath(data_path))
if os.path.exists(data_path):
    print("File found!")
else:
    print("File not found!")
# Out:
# Attempting to access: ../Data/data_angles/data3_angles.csv
# Full path: /home/exx/Desktop/quantum/Data/data_angles/data3_angles.csv
# File found!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# NameError: name 'torch' is not defined

# %%
print(device)
# Out:
# cuda

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import GradScaler, autocast
import matplotlib.pyplot as plt
from typing import Tuple

# Verify GPU
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("GPU count:", torch.cuda.device_count())
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected, exiting!")
    exit(1)

class AngleDataset(Dataset):
    def __init__(self, data_path: str, window_size: int, indices: np.ndarray = None):
        self.df = pd.read_csv(data_path)
        if self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                   'Target Phi (degrees)', 'Target Theta (degrees)']].isna().any().any():
            print("Warning: NaN values found in data!")
            self.df = self.df.dropna()
        if np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                            'Target Phi (degrees)', 'Target Theta (degrees)']].values).any():
            print("Warning: Infinite values found in data!")
            self.df = self.df[~np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                                                'Target Phi (degrees)', 'Target Theta (degrees)']]).any(axis=1)]
        
        self.features = self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)']].values
        self.targets = self.df[['Target Phi (degrees)', 'Target Theta (degrees)']].values
        self.features[:, 0] /= 180.0
        self.features[:, 1] /= 180.0
        self.targets[:, 0] /= 180.0
        self.targets[:, 1] /= 180.0
        
        print("Normalized Feature Phi range:", self.features[:, 0].min(), "to", self.features[:, 0].max())
        print("Normalized Feature Theta range:", self.features[:, 1].min(), "to", self.features[:, 1].max())
        print("Normalized Target Phi range:", self.targets[:, 0].min(), "to", self.targets[:, 0].max())
        print("Normalized Target Theta range:", self.targets[:, 1].min(), "to", self.targets[:, 1].max())
        
        self.window_size = window_size
        self.indices = indices if indices is not None else np.arange(len(self.df) - window_size + 1)
        self.length = len(self.indices)

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, int]:
        data_idx = self.indices[idx]
        window = self.features[data_idx:data_idx + self.window_size]
        target = self.targets[data_idx + self.window_size - 1]
        time_index = data_idx + self.window_size - 1
        return torch.FloatTensor(window), torch.FloatTensor(target), time_index

class FlashAttention(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_heads == 0, "d_model must be divisible by n_heads"
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.dropout = nn.Dropout(dropout)
        
        self.qkv = nn.Linear(d_model, 3 * d_model)
        self.out = nn.Linear(d_model, d_model)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, T, C = x.shape
        qkv = self.qkv(x).reshape(B, T, 3, self.n_heads, self.d_k).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = 1.0 / torch.sqrt(torch.tensor(self.d_k, dtype=torch.float32))
        attn = torch.matmul(q, k.transpose(-2, -1)) * scale
        attn = F.softmax(attn, dim=-1)
        attn = self.dropout(attn)
        
        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).reshape(B, T, C)
        out = self.out(out)
        return out

class AnglePredictionModel(nn.Module):
    def __init__(self, input_dim: int, d_model: int, n_heads: int, n_layers: int, dropout: float = 0.1):
        super().__init__()
        self.input_dim = input_dim
        self.d_model = d_model
        
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_encoding = nn.Parameter(torch.randn(1, 128, d_model) * 0.1)
        self.attn_layers = nn.ModuleList([
            FlashAttention(d_model, n_heads, dropout) for _ in range(n_layers)
        ])
        self.norm_layers = nn.ModuleList([
            nn.LayerNorm(d_model) for _ in range(n_layers)
        ])
        self.output = nn.Linear(d_model, 2)
        
        self.apply(self._init_weights)
    
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.xavier_uniform_(module.weight)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.input_proj(x)
        x = x + self.pos_encoding[:, :x.size(1), :]
        
        for attn, norm in zip(self.attn_layers, self.norm_layers):
            residual = x
            x = attn(x)
            x = norm(x + residual)
        
        x = x[:, -1, :]
        return self.output(x)

def train_model(model: nn.Module, train_loader: DataLoader, test_loader: DataLoader, 
                epochs: int, device: torch.device, lr: float = 1e-4):
    print("Model device:", next(model.parameters()).device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    scaler = torch.amp.GradScaler('cuda')
    criterion = nn.MSELoss()
    
    train_losses, test_losses = [], []
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for i, (batch_x, batch_y, _) in enumerate(train_loader):
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            if i == 0:
                print("Batch x device:", batch_x.device)
            
            optimizer.zero_grad()
            with torch.amp.autocast('cuda'):
                output = model(batch_x)
                if torch.isnan(output).any():
                    print(f"NaN in output at epoch {epoch+1}, batch {i}")
                    break
                loss = criterion(output, batch_y)
            
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y, _ in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                test_loss += criterion(output, batch_y).item()
        
        test_loss /= len(test_loader)
        test_losses.append(test_loss)
        
        scheduler.step()
        
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")
    
    return train_losses, test_losses

def plot_predictions(predictions: np.ndarray, actuals: np.ndarray, time_indices: np.ndarray, 
                     rmse_phi: float, rmse_theta: float, filename: str, title_prefix: str):
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, actuals[:, 0], label='Actual Phi (1551 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 0], label='Predicted Phi (from 1531 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Phi Time Series (RMSE: {rmse_phi:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Phi (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, actuals[:, 1], label='Actual Theta (1551 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 1], label='Predicted Theta (from 1531 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Theta Time Series (RMSE: {rmse_theta:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Theta (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()
    
    errors = np.abs(predictions - actuals)
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, errors[:, 0], label='|Predicted - Actual| Phi', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Phi Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, errors[:, 1], label='|Predicted - Actual| Theta', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Theta Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(f'errors_{filename.split("_", 1)[1]}')
    plt.close()

def experiment_window_sizes(data_path: str, window_sizes: list, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results = {}
    
    for window_size in window_sizes:
        print(f"\nExperimenting with window size: {window_size}")
        
        dataset_full = AngleDataset(data_path, window_size)
        total_length = len(dataset_full)
        train_length = int(0.8 * total_length)
        test_length = total_length - train_length
        
        train_indices = np.arange(train_length)
        test_indices = np.arange(train_length, total_length)
        
        train_dataset = AngleDataset(data_path, window_size, train_indices)
        test_dataset = AngleDataset(data_path, window_size, test_indices)
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=140,
            n_heads=4,
            n_layers=4,
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        time_indices = time_indices[sort_idx]
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        plot_predictions(
            predictions, actuals, time_indices, rmse_phi, rmse_theta,
            f'predictions_window_{window_size}.png',
            f'Window Size {window_size}'
        )
        
        results[window_size] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'model': model,
            'predictions': predictions,
            'actuals': actuals,
            'time_indices': time_indices,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Window Size: {window_size})')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_window_{window_size}.png')
        plt.close()
    
    plt.figure(figsize=(12, 6))
    for window_size, result in results.items():
        plt.plot(result['test_losses'], label=f'Window {window_size}')
    plt.title('Test Loss Comparison Across Window Sizes')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('window_size_comparison.png')
    plt.close()
    
    return results

def experiment_model_sizes(data_path: str, window_size: int = 64, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_configs = [
        {'name': 'small', 'd_model': 16, 'n_heads': 4, 'n_layers': 1},
        {'name': 'medium', 'd_model': 32, 'n_heads': 4, 'n_layers': 2},
        {'name': 'large', 'd_model': 64, 'n_heads': 8, 'n_layers': 3},
        # Extra Large: Increase d_model to ~140 to get ~5x parameters
        {'name': 'extra_large', 'd_model': 140, 'n_heads': 10, 'n_layers': 4}
    ]
    results = {}
    
    dataset_full = AngleDataset(data_path, window_size)
    total_length = len(dataset_full)
    train_length = int(0.8 * total_length)
    test_length = total_length - train_length

    train_indices = np.arange(train_length)
    test_indices = np.arange(train_length, total_length)

    train_dataset = AngleDataset(data_path, window_size, train_indices)
    test_dataset = AngleDataset(data_path, window_size, test_indices)

    rmse_phi_list = []
    rmse_theta_list = []
    model_names = []

    for config in model_configs:
        model_name = config['name']
        print(f"\nExperimenting with model size: {model_name} (d_model={config['d_model']}, "
              f"n_layers={config['n_layers']}, n_heads={config['n_heads']})")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=config['d_model'],
            n_heads=config['n_heads'],
            n_layers=config['n_layers'],
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        # Evaluation Phase
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        rmse_phi_list.append(rmse_phi)
        rmse_theta_list.append(rmse_theta)
        model_names.append(model_name.capitalize())
        
        # Existing plots
        plot_predictions(
            predictions, actuals, time_indices[sort_idx], rmse_phi, rmse_theta,
            f'predictions_model_{model_name}.png',
            f'Model {model_name.capitalize()} (Window Size {window_size})'
        )
        
        results[model_name] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }

        # Loss Curve Plot
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Model: {model_name}, Window Size: {window_size})')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_model_{model_name}.png')
        plt.close()
    
    # Plot RMSE Comparison Chart
    x = np.arange(len(model_names))
    width = 0.35

    plt.figure(figsize=(10, 6))
    plt.bar(x - width/2, rmse_phi_list, width, label='RMSE Phi')
    plt.bar(x + width/2, rmse_theta_list, width, label='RMSE Theta')
    plt.xticks(x, model_names)
    plt.ylabel('RMSE (degrees)')
    plt.title('RMSE Comparison Across Model Sizes')
    plt.legend()
    plt.grid(True, axis='y')
    plt.tight_layout()
    plt.savefig('rmse_model_comparison.png')
    plt.close()
    
    return results


if __name__ == "__main__":
    data_path = os.path.join("..", "Data", "data_angles", "data3_angles.csv")
    
    print("Attempting to access:", data_path)
    print("Full path:", os.path.abspath(data_path))
    if os.path.exists(data_path):
        print("File found!")
    else:
        print("File not found!")
        exit(1)
    
    # Experiment 1: Window sizes
    window_sizes = [8, 16, 32, 64, 128]
    window_results = experiment_window_sizes(data_path, window_sizes)
    
    # Experiment 2: Model sizes for window_size=64
    model_results = experiment_model_sizes(data_path, window_size=16)
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.4
# GPU count: 1
# GPU name: NVIDIA H100 NVL
# Attempting to access: ../Data/data_angles/data3_angles.csv
# Full path: /home/exx/Desktop/quantum/Data/data_angles/data3_angles.csv
# File found!
#
# Experimenting with window size: 8
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0437, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0280, Test Loss: 0.0126
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0241, Test Loss: 0.0147
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0216, Test Loss: 0.0174
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0205, Test Loss: 0.0203
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0198, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0192, Test Loss: 0.0249
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0186, Test Loss: 0.0267
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0182, Test Loss: 0.0217
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0178, Test Loss: 0.0272
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0170, Test Loss: 0.0376
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0167, Test Loss: 0.0325
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0163, Test Loss: 0.0307
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0159, Test Loss: 0.0253
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0155, Test Loss: 0.0433
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0151, Test Loss: 0.0350
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0151, Test Loss: 0.0356
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0148, Test Loss: 0.0346
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0145, Test Loss: 0.0423
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0142, Test Loss: 0.0530
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0139, Test Loss: 0.0405
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0139, Test Loss: 0.0494
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0135, Test Loss: 0.0456
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0132, Test Loss: 0.0413
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0131, Test Loss: 0.0506
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0129, Test Loss: 0.0453
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0127, Test Loss: 0.0437
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0125, Test Loss: 0.0509
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0124, Test Loss: 0.0531
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0121, Test Loss: 0.0626
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0120, Test Loss: 0.0504
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0118, Test Loss: 0.0601
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0117, Test Loss: 0.0487
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0116, Test Loss: 0.0598
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0114, Test Loss: 0.0578
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0114, Test Loss: 0.0596
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0113, Test Loss: 0.0570
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0111, Test Loss: 0.0555
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0111, Test Loss: 0.0570
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0109, Test Loss: 0.0578
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0108, Test Loss: 0.0587
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0108, Test Loss: 0.0605
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0107, Test Loss: 0.0586
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0106, Test Loss: 0.0591
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0106, Test Loss: 0.0597
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0107, Test Loss: 0.0575
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0104, Test Loss: 0.0566
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0107, Test Loss: 0.0584
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0105, Test Loss: 0.0585
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0105, Test Loss: 0.0585
#
# Experimenting with window size: 16
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0718, Test Loss: 0.0135
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0273, Test Loss: 0.0088
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0231, Test Loss: 0.0144
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0205, Test Loss: 0.0181
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0199, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0195, Test Loss: 0.0142
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0189, Test Loss: 0.0288
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0187, Test Loss: 0.0180
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0182, Test Loss: 0.0228
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0180, Test Loss: 0.0291
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0172, Test Loss: 0.0194
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0166, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0159, Test Loss: 0.0307
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0154, Test Loss: 0.0449
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0148, Test Loss: 0.0356
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0147, Test Loss: 0.0419
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0139, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0137, Test Loss: 0.0389
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0131, Test Loss: 0.0419
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0129, Test Loss: 0.0463
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0124, Test Loss: 0.0520
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0125, Test Loss: 0.0508
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0126, Test Loss: 0.0312
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0120, Test Loss: 0.0422
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0116, Test Loss: 0.0402
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0113, Test Loss: 0.0479
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0114, Test Loss: 0.0425
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0113, Test Loss: 0.0540
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0109, Test Loss: 0.0568
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0110, Test Loss: 0.0481
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0107, Test Loss: 0.0483
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0106, Test Loss: 0.0561
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0104, Test Loss: 0.0460
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0102, Test Loss: 0.0514
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0101, Test Loss: 0.0504
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0101, Test Loss: 0.0566
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0099, Test Loss: 0.0542
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0098, Test Loss: 0.0543
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0096, Test Loss: 0.0532
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0098, Test Loss: 0.0468
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0096, Test Loss: 0.0537
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0094, Test Loss: 0.0521
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0094, Test Loss: 0.0505
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0093, Test Loss: 0.0546
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0093, Test Loss: 0.0540
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0092, Test Loss: 0.0556
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0092, Test Loss: 0.0543
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0092, Test Loss: 0.0540
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0092, Test Loss: 0.0540
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0091, Test Loss: 0.0538
#
# Experimenting with window size: 32
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0670, Test Loss: 0.0171
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0268, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0226, Test Loss: 0.0137
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0201, Test Loss: 0.0164
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0196, Test Loss: 0.0167
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0186, Test Loss: 0.0221
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0182, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0181, Test Loss: 0.0259
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0176, Test Loss: 0.0180
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0168, Test Loss: 0.0256
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0163, Test Loss: 0.0180
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0157, Test Loss: 0.0275
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0155, Test Loss: 0.0380
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0152, Test Loss: 0.0383
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0145, Test Loss: 0.0311
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0141, Test Loss: 0.0372
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0137, Test Loss: 0.0357
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0133, Test Loss: 0.0386
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0128, Test Loss: 0.0392
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0126, Test Loss: 0.0401
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0122, Test Loss: 0.0368
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0119, Test Loss: 0.0487
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0116, Test Loss: 0.0406
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0112, Test Loss: 0.0451
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0113, Test Loss: 0.0521
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0107, Test Loss: 0.0422
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0107, Test Loss: 0.0491
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0104, Test Loss: 0.0476
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0105, Test Loss: 0.0420
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0100, Test Loss: 0.0459
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0100, Test Loss: 0.0466
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0098, Test Loss: 0.0457
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0096, Test Loss: 0.0465
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0094, Test Loss: 0.0462
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0093, Test Loss: 0.0505
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0092, Test Loss: 0.0433
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0092, Test Loss: 0.0534
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0091, Test Loss: 0.0425
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0089, Test Loss: 0.0513
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0089, Test Loss: 0.0519
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0087, Test Loss: 0.0482
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0086, Test Loss: 0.0466
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0086, Test Loss: 0.0524
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0085, Test Loss: 0.0435
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0086, Test Loss: 0.0452
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0085, Test Loss: 0.0477
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0084, Test Loss: 0.0451
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0083, Test Loss: 0.0467
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0084, Test Loss: 0.0471
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0084, Test Loss: 0.0466
#
# Experimenting with window size: 64
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0402, Test Loss: 0.0185
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0264, Test Loss: 0.0129
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0229, Test Loss: 0.0117
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0204, Test Loss: 0.0228
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0193, Test Loss: 0.0164
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0188, Test Loss: 0.0161
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0182, Test Loss: 0.0166
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0176, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0167, Test Loss: 0.0217
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0161, Test Loss: 0.0196
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0154, Test Loss: 0.0178
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0145, Test Loss: 0.0322
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0138, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0132, Test Loss: 0.0272
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0127, Test Loss: 0.0286
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0123, Test Loss: 0.0390
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0120, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0114, Test Loss: 0.0288
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0112, Test Loss: 0.0340
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0106, Test Loss: 0.0409
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0105, Test Loss: 0.0338
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0101, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0097, Test Loss: 0.0312
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0095, Test Loss: 0.0276
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0089, Test Loss: 0.0280
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0085, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0082, Test Loss: 0.0243
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0078, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0076, Test Loss: 0.0327
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0075, Test Loss: 0.0277
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0069, Test Loss: 0.0331
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0068, Test Loss: 0.0330
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0067, Test Loss: 0.0322
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0066, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0064, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0062, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0060, Test Loss: 0.0293
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0061, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0059, Test Loss: 0.0329
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0059, Test Loss: 0.0275
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0058, Test Loss: 0.0285
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0057, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0056, Test Loss: 0.0303
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0055, Test Loss: 0.0295
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0055, Test Loss: 0.0298
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0054, Test Loss: 0.0293
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0054, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0055, Test Loss: 0.0300
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0054, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0054, Test Loss: 0.0299
#
# Experimenting with window size: 128
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0369, Test Loss: 0.0168
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0257, Test Loss: 0.0177
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0202, Test Loss: 0.0236
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0186, Test Loss: 0.0201
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0181, Test Loss: 0.0147
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0173, Test Loss: 0.0175
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0169, Test Loss: 0.0167
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0160, Test Loss: 0.0234
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0152, Test Loss: 0.0169
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0139, Test Loss: 0.0251
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0130, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0121, Test Loss: 0.0217
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0115, Test Loss: 0.0199
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0109, Test Loss: 0.0302
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0103, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0099, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0096, Test Loss: 0.0220
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0088, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0087, Test Loss: 0.0225
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0086, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0080, Test Loss: 0.0269
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0081, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0076, Test Loss: 0.0191
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0073, Test Loss: 0.0188
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0071, Test Loss: 0.0221
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0067, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0064, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0063, Test Loss: 0.0204
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0061, Test Loss: 0.0221
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0060, Test Loss: 0.0241
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0057, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0057, Test Loss: 0.0208
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0054, Test Loss: 0.0195
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0053, Test Loss: 0.0249
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0051, Test Loss: 0.0195
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0051, Test Loss: 0.0207
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0051, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0049, Test Loss: 0.0208
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0046, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0047, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0046, Test Loss: 0.0211
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0046, Test Loss: 0.0209
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0045, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0045, Test Loss: 0.0208
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0042, Test Loss: 0.0203
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0043, Test Loss: 0.0209
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0044, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0042, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0042, Test Loss: 0.0207
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0043, Test Loss: 0.0207
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
# Normalized Feature Phi range: -0.9978134564358532 to 0.9996863483598596
# Normalized Feature Theta range: 0.11361577442323839 to 0.9864661411132395
# Normalized Target Phi range: -0.9890286607741708 to 0.9963408852394541
# Normalized Target Theta range: 0.00044620780969745 to 0.8263618152322757
#
# Experimenting with model size: small (d_model=16, n_layers=1, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.1104, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0310, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0303, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0299, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0297, Test Loss: 0.0196
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0295, Test Loss: 0.0210
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0294, Test Loss: 0.0233
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0293, Test Loss: 0.0224
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0292, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0291, Test Loss: 0.0222
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0291, Test Loss: 0.0222
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0290, Test Loss: 0.0234
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0289, Test Loss: 0.0217
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0289, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0289, Test Loss: 0.0239
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0288, Test Loss: 0.0208
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0288, Test Loss: 0.0192
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0288, Test Loss: 0.0221
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0287, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0287, Test Loss: 0.0223
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0287, Test Loss: 0.0203
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0287, Test Loss: 0.0203
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0287, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0287, Test Loss: 0.0217
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0287, Test Loss: 0.0222
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0286, Test Loss: 0.0210
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0286, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0286, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0286, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0286, Test Loss: 0.0203
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0286, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0286, Test Loss: 0.0207
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0286, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0286, Test Loss: 0.0204
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0286, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0286, Test Loss: 0.0211
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0285, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0285, Test Loss: 0.0210
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0285, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0285, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0285, Test Loss: 0.0211
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0285, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0285, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0285, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0285, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0285, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0285, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0285, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0285, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0285, Test Loss: 0.0213
#
# Experimenting with model size: medium (d_model=32, n_layers=2, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.1698, Test Loss: 0.0268
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0305, Test Loss: 0.0200
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0290, Test Loss: 0.0181
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0279, Test Loss: 0.0171
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0268, Test Loss: 0.0175
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0260, Test Loss: 0.0134
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0255, Test Loss: 0.0158
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0247, Test Loss: 0.0196
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0237, Test Loss: 0.0186
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0227, Test Loss: 0.0179
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0216, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0208, Test Loss: 0.0169
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0204, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0198, Test Loss: 0.0193
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0197, Test Loss: 0.0221
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0194, Test Loss: 0.0194
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0192, Test Loss: 0.0230
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0192, Test Loss: 0.0193
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0190, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0189, Test Loss: 0.0247
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0188, Test Loss: 0.0207
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0187, Test Loss: 0.0203
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0186, Test Loss: 0.0217
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0186, Test Loss: 0.0196
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0184, Test Loss: 0.0190
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0184, Test Loss: 0.0201
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0184, Test Loss: 0.0258
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0183, Test Loss: 0.0201
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0182, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0182, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0181, Test Loss: 0.0212
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0181, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0181, Test Loss: 0.0205
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0180, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0180, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0179, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0178, Test Loss: 0.0213
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0179, Test Loss: 0.0223
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0178, Test Loss: 0.0201
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0178, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0178, Test Loss: 0.0224
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0177, Test Loss: 0.0225
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0177, Test Loss: 0.0219
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0177, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0177, Test Loss: 0.0223
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0177, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0177, Test Loss: 0.0225
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0177, Test Loss: 0.0223
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0177, Test Loss: 0.0224
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0177, Test Loss: 0.0223
#
# Experimenting with model size: large (d_model=64, n_layers=3, n_heads=8)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0366, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0297, Test Loss: 0.0187
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0281, Test Loss: 0.0186
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0273, Test Loss: 0.0190
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0260, Test Loss: 0.0132
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0244, Test Loss: 0.0179
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0226, Test Loss: 0.0148
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0213, Test Loss: 0.0174
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0206, Test Loss: 0.0257
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0200, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0196, Test Loss: 0.0244
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0194, Test Loss: 0.0155
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0190, Test Loss: 0.0164
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0187, Test Loss: 0.0218
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0184, Test Loss: 0.0212
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0182, Test Loss: 0.0174
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0181, Test Loss: 0.0192
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0178, Test Loss: 0.0233
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0176, Test Loss: 0.0219
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0173, Test Loss: 0.0225
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0171, Test Loss: 0.0256
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0171, Test Loss: 0.0254
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0167, Test Loss: 0.0269
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0165, Test Loss: 0.0240
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0162, Test Loss: 0.0248
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0159, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0159, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0157, Test Loss: 0.0364
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0156, Test Loss: 0.0344
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0154, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0151, Test Loss: 0.0367
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0151, Test Loss: 0.0398
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0149, Test Loss: 0.0377
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0147, Test Loss: 0.0415
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0148, Test Loss: 0.0362
# Batch x device: cuda:0
