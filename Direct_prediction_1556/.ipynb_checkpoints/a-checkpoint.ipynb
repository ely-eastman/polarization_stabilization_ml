# %%
import os
data_path = "../Data/data_angles/data6_angles.csv"
print("Attempting to access:", data_path)
print("Full path:", os.path.abspath(data_path))
if os.path.exists(data_path):
    print("File found!")
else:
    print("File not found!")
# Out:
# Attempting to access: ../Data/data_angles/data6_angles.csv
# Full path: /home/exx/Desktop/quantum/Data/data_angles/data6_angles.csv
# File found!

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import GradScaler, autocast
import matplotlib.pyplot as plt
from typing import Tuple

# Verify GPU
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("GPU count:", torch.cuda.device_count())
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected, exiting!")
    exit(1)

class AngleDataset(Dataset):
    def __init__(self, data_path: str, window_size: int, indices: np.ndarray = None):
        self.df = pd.read_csv(data_path)
        if self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                   'Target Phi (degrees)', 'Target Theta (degrees)']].isna().any().any():
            print("Warning: NaN values found in data!")
            self.df = self.df.dropna()
        if np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                            'Target Phi (degrees)', 'Target Theta (degrees)']].values).any():
            print("Warning: Infinite values found in data!")
            self.df = self.df[~np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                                                'Target Phi (degrees)', 'Target Theta (degrees)']]).any(axis=1)]
        
        self.features = self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)']].values
        self.targets = self.df[['Target Phi (degrees)', 'Target Theta (degrees)']].values
        self.features[:, 0] /= 180.0
        self.features[:, 1] /= 180.0
        self.targets[:, 0] /= 180.0
        self.targets[:, 1] /= 180.0
        
        print("Normalized Feature Phi range:", self.features[:, 0].min(), "to", self.features[:, 0].max())
        print("Normalized Feature Theta range:", self.features[:, 1].min(), "to", self.features[:, 1].max())
        print("Normalized Target Phi range:", self.targets[:, 0].min(), "to", self.targets[:, 0].max())
        print("Normalized Target Theta range:", self.targets[:, 1].min(), "to", self.targets[:, 1].max())
        
        self.window_size = window_size
        self.indices = indices if indices is not None else np.arange(len(self.df) - window_size + 1)
        self.length = len(self.indices)

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, int]:
        data_idx = self.indices[idx]
        window = self.features[data_idx:data_idx + self.window_size]
        target = self.targets[data_idx + self.window_size - 1]
        time_index = data_idx + self.window_size - 1
        return torch.FloatTensor(window), torch.FloatTensor(target), time_index

class FlashAttention(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_heads == 0, "d_model must be divisible by n_heads"
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.dropout = nn.Dropout(dropout)
        
        self.qkv = nn.Linear(d_model, 3 * d_model)
        self.out = nn.Linear(d_model, d_model)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, T, C = x.shape
        qkv = self.qkv(x).reshape(B, T, 3, self.n_heads, self.d_k).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = 1.0 / torch.sqrt(torch.tensor(self.d_k, dtype=torch.float32))
        attn = torch.matmul(q, k.transpose(-2, -1)) * scale
        attn = F.softmax(attn, dim=-1)
        attn = self.dropout(attn)
        
        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).reshape(B, T, C)
        out = self.out(out)
        return out

class AnglePredictionModel(nn.Module):
    def __init__(self, input_dim: int, d_model: int, n_heads: int, n_layers: int, dropout: float = 0.1):
        super().__init__()
        self.input_dim = input_dim
        self.d_model = d_model
        
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_encoding = nn.Parameter(torch.randn(1, 128, d_model) * 0.1)
        self.attn_layers = nn.ModuleList([
            FlashAttention(d_model, n_heads, dropout) for _ in range(n_layers)
        ])
        self.norm_layers = nn.ModuleList([
            nn.LayerNorm(d_model) for _ in range(n_layers)
        ])
        self.output = nn.Linear(d_model, 2)
        
        self.apply(self._init_weights)
    
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.xavier_uniform_(module.weight)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.input_proj(x)
        x = x + self.pos_encoding[:, :x.size(1), :]
        
        for attn, norm in zip(self.attn_layers, self.norm_layers):
            residual = x
            x = attn(x)
            x = norm(x + residual)
        
        x = x[:, -1, :]
        return self.output(x)

def train_model(model: nn.Module, train_loader: DataLoader, test_loader: DataLoader, 
                epochs: int, device: torch.device, lr: float = 1e-4):
    print("Model device:", next(model.parameters()).device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    scaler = torch.amp.GradScaler('cuda')
    criterion = nn.MSELoss()
    
    train_losses, test_losses = [], []
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for i, (batch_x, batch_y, _) in enumerate(train_loader):
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            if i == 0:
                print("Batch x device:", batch_x.device)
            
            optimizer.zero_grad()
            with torch.amp.autocast('cuda'):
                output = model(batch_x)
                if torch.isnan(output).any():
                    print(f"NaN in output at epoch {epoch+1}, batch {i}")
                    break
                loss = criterion(output, batch_y)
            
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y, _ in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                test_loss += criterion(output, batch_y).item()
        
        test_loss /= len(test_loader)
        test_losses.append(test_loss)
        
        scheduler.step()
        
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")
    
    return train_losses, test_losses

def plot_predictions(predictions: np.ndarray, actuals: np.ndarray, time_indices: np.ndarray, 
                     rmse_phi: float, rmse_theta: float, filename: str, title_prefix: str):
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, actuals[:, 0], label='Actual Phi (1550 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 0], label='Predicted Phi (from 1556 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Phi Time Series (RMSE: {rmse_phi:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Phi (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, actuals[:, 1], label='Actual Theta (1550 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 1], label='Predicted Theta (from 1556 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Theta Time Series (RMSE: {rmse_theta:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Theta (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()
    
    errors = np.abs(predictions - actuals)
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, errors[:, 0], label='|Predicted - Actual| Phi', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Phi Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, errors[:, 1], label='|Predicted - Actual| Theta', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Theta Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(f'errors_{filename.split("_", 1)[1]}')
    plt.close()

def experiment_window_sizes(data_path: str, window_sizes: list, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results = {}
    
    for window_size in window_sizes:
        print(f"\nExperimenting with window size: {window_size}")
        
        dataset_full = AngleDataset(data_path, window_size)
        total_length = len(dataset_full)
        train_length = int(0.8 * total_length)
        test_length = total_length - train_length
        
        train_indices = np.arange(train_length)
        test_indices = np.arange(train_length, total_length)
        
        train_dataset = AngleDataset(data_path, window_size, train_indices)
        test_dataset = AngleDataset(data_path, window_size, test_indices)
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=32,
            n_heads=4,
            n_layers=2,
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        time_indices = time_indices[sort_idx]
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        plot_predictions(
            predictions, actuals, time_indices, rmse_phi, rmse_theta,
            f'predictions_window_{window_size}.png',
            f'Window Size {window_size}'
        )
        
        results[window_size] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'model': model,
            'predictions': predictions,
            'actuals': actuals,
            'time_indices': time_indices,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Window Size: {window_size})')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_window_{window_size}.png')
        plt.close()
    
    plt.figure(figsize=(12, 6))
    for window_size, result in results.items():
        plt.plot(result['test_losses'], label=f'Window {window_size}')
    plt.title('Test Loss Comparison Across Window Sizes')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('window_size_comparison.png')
    plt.close()
    
    return results

def experiment_model_sizes(data_path: str, window_size: int = 64, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_configs = [
        {'name': 'small', 'd_model': 16, 'n_heads': 4, 'n_layers': 1},
        {'name': 'medium', 'd_model': 32, 'n_heads': 4, 'n_layers': 2},
        {'name': 'large', 'd_model': 64, 'n_heads': 8, 'n_layers': 3}
    ]
    results = {}
    
    dataset_full = AngleDataset(data_path, window_size)
    total_length = len(dataset_full)
    train_length = int(0.8 * total_length)
    test_length = total_length - train_length
    
    train_indices = np.arange(train_length)
    test_indices = np.arange(train_length, total_length)
    
    train_dataset = AngleDataset(data_path, window_size, train_indices)
    test_dataset = AngleDataset(data_path, window_size, test_indices)
    
    for config in model_configs:
        model_name = config['name']
        print(f"\nExperimenting with model size: {model_name} (d_model={config['d_model']}, "
              f"n_layers={config['n_layers']}, n_heads={config['n_heads']})")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=config['d_model'],
            n_heads=config['n_heads'],
            n_layers=config['n_layers'],
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        time_indices = time_indices[sort_idx]
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        plot_predictions(
            predictions, actuals, time_indices, rmse_phi, rmse_theta,
            f'predictions_model_{model_name}.png',
            f'Model {model_name.capitalize()} (Window Size 64)'
        )
        
        results[model_name] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'model': model,
            'predictions': predictions,
            'actuals': actuals,
            'time_indices': time_indices,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Model: {model_name}, Window Size: 64)')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_model_{model_name}.png')
        plt.close()
    
    plt.figure(figsize=(12, 6))
    for model_name, result in results.items():
        plt.plot(result['test_losses'], label=f'Model {model_name}')
    plt.title('Test Loss Comparison Across Model Sizes (Window Size: 64)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('model_size_comparison_window_64.png')
    plt.close()
    
    return results

if __name__ == "__main__":
    data_path = os.path.join("..", "Data", "data_angles", "data6_angles.csv")
    
    print("Attempting to access:", data_path)
    print("Full path:", os.path.abspath(data_path))
    if os.path.exists(data_path):
        print("File found!")
    else:
        print("File not found!")
        exit(1)
    
    # Experiment 1: Window sizes
    window_sizes = [8, 16, 32, 64, 128]
    window_results = experiment_window_sizes(data_path, window_sizes)
    
    # Experiment 2: Model sizes for window_size=64
    model_results = experiment_model_sizes(data_path, window_size=64)
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.4
# GPU count: 1
# GPU name: NVIDIA H100 NVL
# Attempting to access: ../Data/data_angles/data6_angles.csv
# Full path: /home/exx/Desktop/quantum/Data/data_angles/data6_angles.csv
# File found!
#
# Experimenting with window size: 8
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.2113, Test Loss: 0.0783
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1143, Test Loss: 0.0659
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0953, Test Loss: 0.0576
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0841, Test Loss: 0.0426
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0773, Test Loss: 0.0381
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0732, Test Loss: 0.0365
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0683, Test Loss: 0.0329
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0668, Test Loss: 0.0312
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0628, Test Loss: 0.0303
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0600, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0581, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0542, Test Loss: 0.0269
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0522, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0497, Test Loss: 0.0249
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0474, Test Loss: 0.0249
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0459, Test Loss: 0.0233
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0443, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0428, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0418, Test Loss: 0.0215
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0405, Test Loss: 0.0216
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0392, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0378, Test Loss: 0.0202
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0386, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0378, Test Loss: 0.0209
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0364, Test Loss: 0.0197
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0365, Test Loss: 0.0202
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0360, Test Loss: 0.0191
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0359, Test Loss: 0.0192
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0355, Test Loss: 0.0194
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0347, Test Loss: 0.0188
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0346, Test Loss: 0.0194
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0354, Test Loss: 0.0187
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0346, Test Loss: 0.0186
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0344, Test Loss: 0.0188
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0344, Test Loss: 0.0185
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0333, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0334, Test Loss: 0.0185
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0337, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0339, Test Loss: 0.0188
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0329, Test Loss: 0.0185
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0341, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0342, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0332, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0335, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0332, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0338, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0336, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0329, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0336, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0327, Test Loss: 0.0183
#
# Experimenting with window size: 16
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.8406, Test Loss: 0.2734
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1731, Test Loss: 0.1081
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1171, Test Loss: 0.0792
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0983, Test Loss: 0.0628
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0879, Test Loss: 0.0538
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0809, Test Loss: 0.0492
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0781, Test Loss: 0.0457
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0748, Test Loss: 0.0413
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0721, Test Loss: 0.0425
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0702, Test Loss: 0.0385
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0684, Test Loss: 0.0385
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0664, Test Loss: 0.0364
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0639, Test Loss: 0.0354
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0626, Test Loss: 0.0342
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0613, Test Loss: 0.0345
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0593, Test Loss: 0.0332
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0576, Test Loss: 0.0322
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0561, Test Loss: 0.0310
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0543, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0535, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0514, Test Loss: 0.0304
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0505, Test Loss: 0.0289
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0480, Test Loss: 0.0284
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0468, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0451, Test Loss: 0.0278
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0442, Test Loss: 0.0278
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0428, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0422, Test Loss: 0.0272
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0407, Test Loss: 0.0257
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0403, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0394, Test Loss: 0.0252
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0394, Test Loss: 0.0250
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0387, Test Loss: 0.0247
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0379, Test Loss: 0.0248
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0381, Test Loss: 0.0249
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0368, Test Loss: 0.0245
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0366, Test Loss: 0.0242
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0372, Test Loss: 0.0245
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0370, Test Loss: 0.0242
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0363, Test Loss: 0.0244
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0367, Test Loss: 0.0242
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0358, Test Loss: 0.0240
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0358, Test Loss: 0.0240
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0357, Test Loss: 0.0240
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0357, Test Loss: 0.0239
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0365, Test Loss: 0.0240
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0366, Test Loss: 0.0239
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0366, Test Loss: 0.0239
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0361, Test Loss: 0.0239
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0362, Test Loss: 0.0239
#
# Experimenting with window size: 32
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.4266, Test Loss: 0.1248
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1239, Test Loss: 0.0905
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1016, Test Loss: 0.0751
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0896, Test Loss: 0.0602
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0808, Test Loss: 0.0469
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0748, Test Loss: 0.0426
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0690, Test Loss: 0.0393
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0662, Test Loss: 0.0378
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0624, Test Loss: 0.0376
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0609, Test Loss: 0.0351
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0581, Test Loss: 0.0353
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0567, Test Loss: 0.0350
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0548, Test Loss: 0.0349
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0537, Test Loss: 0.0334
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0520, Test Loss: 0.0345
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0496, Test Loss: 0.0343
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0489, Test Loss: 0.0330
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0459, Test Loss: 0.0343
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0452, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0440, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0412, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0402, Test Loss: 0.0318
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0386, Test Loss: 0.0314
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0377, Test Loss: 0.0303
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0371, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0359, Test Loss: 0.0298
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0348, Test Loss: 0.0295
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0338, Test Loss: 0.0289
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0332, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0327, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0321, Test Loss: 0.0283
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0313, Test Loss: 0.0282
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0314, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0300, Test Loss: 0.0276
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0306, Test Loss: 0.0276
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0301, Test Loss: 0.0273
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0296, Test Loss: 0.0274
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0298, Test Loss: 0.0272
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0291, Test Loss: 0.0273
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0295, Test Loss: 0.0269
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0291, Test Loss: 0.0270
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0289, Test Loss: 0.0268
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0294, Test Loss: 0.0268
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0287, Test Loss: 0.0267
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0283, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0287, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0283, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0289, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0278, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0284, Test Loss: 0.0266
#
# Experimenting with window size: 64
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.4675, Test Loss: 0.1319
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1350, Test Loss: 0.1070
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1199, Test Loss: 0.0999
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.1076, Test Loss: 0.0919
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0971, Test Loss: 0.0837
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0881, Test Loss: 0.0672
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0807, Test Loss: 0.0582
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0729, Test Loss: 0.0500
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0678, Test Loss: 0.0464
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0634, Test Loss: 0.0471
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0616, Test Loss: 0.0447
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0590, Test Loss: 0.0452
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0570, Test Loss: 0.0433
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0559, Test Loss: 0.0430
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0534, Test Loss: 0.0429
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0529, Test Loss: 0.0423
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0508, Test Loss: 0.0420
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0501, Test Loss: 0.0411
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0482, Test Loss: 0.0379
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0470, Test Loss: 0.0372
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0456, Test Loss: 0.0366
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0443, Test Loss: 0.0350
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0430, Test Loss: 0.0350
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0418, Test Loss: 0.0337
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0403, Test Loss: 0.0323
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0395, Test Loss: 0.0327
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0389, Test Loss: 0.0314
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0375, Test Loss: 0.0315
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0367, Test Loss: 0.0311
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0358, Test Loss: 0.0304
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0356, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0354, Test Loss: 0.0301
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0348, Test Loss: 0.0298
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0344, Test Loss: 0.0292
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0340, Test Loss: 0.0295
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0335, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0329, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0332, Test Loss: 0.0295
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0325, Test Loss: 0.0291
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0326, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0328, Test Loss: 0.0285
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0326, Test Loss: 0.0288
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0327, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0324, Test Loss: 0.0288
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0324, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0320, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0321, Test Loss: 0.0288
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0317, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0324, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0319, Test Loss: 0.0287
#
# Experimenting with window size: 128
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.3132, Test Loss: 0.1006
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1080, Test Loss: 0.0793
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0935, Test Loss: 0.0758
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0867, Test Loss: 0.0657
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0814, Test Loss: 0.0648
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0774, Test Loss: 0.0579
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0735, Test Loss: 0.0541
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0709, Test Loss: 0.0500
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0676, Test Loss: 0.0520
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0646, Test Loss: 0.0470
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0610, Test Loss: 0.0433
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0595, Test Loss: 0.0442
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0571, Test Loss: 0.0409
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0557, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0538, Test Loss: 0.0398
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0527, Test Loss: 0.0386
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0509, Test Loss: 0.0394
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0502, Test Loss: 0.0369
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0483, Test Loss: 0.0374
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0467, Test Loss: 0.0367
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0453, Test Loss: 0.0355
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0441, Test Loss: 0.0345
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0430, Test Loss: 0.0353
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0424, Test Loss: 0.0338
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0410, Test Loss: 0.0337
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0402, Test Loss: 0.0342
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0389, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0383, Test Loss: 0.0322
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0377, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0370, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0365, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0358, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0354, Test Loss: 0.0319
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0351, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0345, Test Loss: 0.0313
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0344, Test Loss: 0.0316
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0342, Test Loss: 0.0314
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0341, Test Loss: 0.0310
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0339, Test Loss: 0.0313
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0336, Test Loss: 0.0312
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0331, Test Loss: 0.0312
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0328, Test Loss: 0.0310
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0331, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0329, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0329, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0328, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0325, Test Loss: 0.0309
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0332, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0324, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0329, Test Loss: 0.0308
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
#
# Experimenting with model size: small (d_model=16, n_layers=1, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 2.0972, Test Loss: 0.3619
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.2442, Test Loss: 0.1626
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1698, Test Loss: 0.1213
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.1482, Test Loss: 0.1042
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.1367, Test Loss: 0.0928
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.1284, Test Loss: 0.0847
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.1217, Test Loss: 0.0800
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.1152, Test Loss: 0.0732
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.1087, Test Loss: 0.0708
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.1027, Test Loss: 0.0657
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0972, Test Loss: 0.0629
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0925, Test Loss: 0.0596
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0883, Test Loss: 0.0588
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0850, Test Loss: 0.0556
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0823, Test Loss: 0.0559
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0797, Test Loss: 0.0511
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0783, Test Loss: 0.0517
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0766, Test Loss: 0.0499
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0751, Test Loss: 0.0499
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0740, Test Loss: 0.0475
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0730, Test Loss: 0.0470
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0721, Test Loss: 0.0455
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0712, Test Loss: 0.0453
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0706, Test Loss: 0.0452
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0701, Test Loss: 0.0441
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0695, Test Loss: 0.0442
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0691, Test Loss: 0.0442
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0687, Test Loss: 0.0444
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0685, Test Loss: 0.0436
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0682, Test Loss: 0.0434
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0678, Test Loss: 0.0432
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0678, Test Loss: 0.0437
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0674, Test Loss: 0.0432
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0674, Test Loss: 0.0429
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0672, Test Loss: 0.0430
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0670, Test Loss: 0.0425
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0669, Test Loss: 0.0428
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0669, Test Loss: 0.0424
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0668, Test Loss: 0.0424
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0664, Test Loss: 0.0428
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0662, Test Loss: 0.0427
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0666, Test Loss: 0.0425
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0663, Test Loss: 0.0422
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0663, Test Loss: 0.0423
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0662, Test Loss: 0.0423
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0664, Test Loss: 0.0424
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0664, Test Loss: 0.0424
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0661, Test Loss: 0.0424
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0662, Test Loss: 0.0424
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0662, Test Loss: 0.0424
#
# Experimenting with model size: medium (d_model=32, n_layers=2, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.3669, Test Loss: 0.0750
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1115, Test Loss: 0.0721
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0940, Test Loss: 0.0715
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0857, Test Loss: 0.0630
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0793, Test Loss: 0.0557
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0747, Test Loss: 0.0545
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0717, Test Loss: 0.0496
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0692, Test Loss: 0.0465
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0663, Test Loss: 0.0444
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0648, Test Loss: 0.0454
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0635, Test Loss: 0.0426
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0614, Test Loss: 0.0402
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0599, Test Loss: 0.0400
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0585, Test Loss: 0.0385
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0572, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0568, Test Loss: 0.0397
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0551, Test Loss: 0.0408
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0540, Test Loss: 0.0393
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0535, Test Loss: 0.0380
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0521, Test Loss: 0.0368
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0509, Test Loss: 0.0352
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0501, Test Loss: 0.0347
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0499, Test Loss: 0.0356
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0476, Test Loss: 0.0349
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0468, Test Loss: 0.0346
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0453, Test Loss: 0.0337
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0449, Test Loss: 0.0341
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0438, Test Loss: 0.0336
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0430, Test Loss: 0.0330
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0430, Test Loss: 0.0323
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0423, Test Loss: 0.0316
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0412, Test Loss: 0.0320
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0406, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0401, Test Loss: 0.0313
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0393, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0395, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0390, Test Loss: 0.0302
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0380, Test Loss: 0.0303
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0388, Test Loss: 0.0301
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0376, Test Loss: 0.0301
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0381, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0381, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0376, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0373, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0374, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0369, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0374, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0371, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0376, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0372, Test Loss: 0.0297
#
# Experimenting with model size: large (d_model=64, n_layers=3, n_heads=8)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.4063, Test Loss: 0.1011
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1056, Test Loss: 0.0686
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0872, Test Loss: 0.0639
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0793, Test Loss: 0.0605
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0747, Test Loss: 0.0537
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0712, Test Loss: 0.0510
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0671, Test Loss: 0.0496
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0642, Test Loss: 0.0466
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0610, Test Loss: 0.0596
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0588, Test Loss: 0.0467
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0559, Test Loss: 0.0414
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0522, Test Loss: 0.0407
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0493, Test Loss: 0.0452
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0442, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0413, Test Loss: 0.0341
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0372, Test Loss: 0.0340
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0339, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0344, Test Loss: 0.0286
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0321, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0296, Test Loss: 0.0273
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0291, Test Loss: 0.0275
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0292, Test Loss: 0.0273
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0263, Test Loss: 0.0257
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0262, Test Loss: 0.0260
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0249, Test Loss: 0.0249
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0251, Test Loss: 0.0245
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0242, Test Loss: 0.0241
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0242, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0239, Test Loss: 0.0242
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0234, Test Loss: 0.0241
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0230, Test Loss: 0.0244
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0223, Test Loss: 0.0231
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0221, Test Loss: 0.0242
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0212, Test Loss: 0.0238
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0215, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0218, Test Loss: 0.0231
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0215, Test Loss: 0.0230
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0221, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0217, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0213, Test Loss: 0.0228
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0209, Test Loss: 0.0229
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0208, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0205, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0211, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0203, Test Loss: 0.0224
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0212, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0202, Test Loss: 0.0226
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0204, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0204, Test Loss: 0.0227
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0201, Test Loss: 0.0226

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda
