# %%
import os
data_path = "../Data/data_angles/data1_angles.csv"
print("Attempting to access:", data_path)
print("Full path:", os.path.abspath(data_path))
if os.path.exists(data_path):
    print("File found!")
else:
    print("File not found!")
# Out:
# Attempting to access: ../Data/data_angles/data1_angles.csv
# Full path: C:\Users\Ely Eastman\Documents\polarization_stabilization_ml\Data\data_angles\data1_angles.csv
# File found!

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# NameError: name 'torch' is not defined

# %%
print(device)
# Out:
# cuda

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import GradScaler, autocast
import matplotlib.pyplot as plt
from typing import Tuple

# %%
# Verify GPU
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("GPU count:", torch.cuda.device_count())
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected, exiting!")
    exit(1)
# Out:
# PyTorch version: 2.7.1+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU count: 1
# GPU name: NVIDIA RTX A2000

# %%
class AngleDataset(Dataset):
    def __init__(self, data_path: str, window_size: int, indices: np.ndarray = None):
        self.df = pd.read_csv(data_path)
        if self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                   'Target Phi (degrees)', 'Target Theta (degrees)']].isna().any().any():
            print("Warning: NaN values found in data!")
            self.df = self.df.dropna()
        if np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                            'Target Phi (degrees)', 'Target Theta (degrees)']].values).any():
            print("Warning: Infinite values found in data!")
            self.df = self.df[~np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                                                'Target Phi (degrees)', 'Target Theta (degrees)']]).any(axis=1)]
        
        self.features = self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)']].values
        self.targets = self.df[['Target Phi (degrees)', 'Target Theta (degrees)']].values
        self.features[:, 0] /= 180.0
        self.features[:, 1] /= 180.0
        self.targets[:, 0] /= 180.0
        self.targets[:, 1] /= 180.0
        
        print("Normalized Feature Phi range:", self.features[:, 0].min(), "to", self.features[:, 0].max())
        print("Normalized Feature Theta range:", self.features[:, 1].min(), "to", self.features[:, 1].max())
        print("Normalized Target Phi range:", self.targets[:, 0].min(), "to", self.targets[:, 0].max())
        print("Normalized Target Theta range:", self.targets[:, 1].min(), "to", self.targets[:, 1].max())
        
        self.window_size = window_size
        self.indices = indices if indices is not None else np.arange(len(self.df) - window_size + 1)
        self.length = len(self.indices)

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, int]:
        data_idx = self.indices[idx]
        window = self.features[data_idx:data_idx + self.window_size]
        target = self.targets[data_idx + self.window_size - 1]
        time_index = data_idx + self.window_size - 1
        return torch.FloatTensor(window), torch.FloatTensor(target), time_index

class FlashAttention(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_heads == 0, "d_model must be divisible by n_heads"
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.dropout = nn.Dropout(dropout)
        
        self.qkv = nn.Linear(d_model, 3 * d_model)
        self.out = nn.Linear(d_model, d_model)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, T, C = x.shape
        qkv = self.qkv(x).reshape(B, T, 3, self.n_heads, self.d_k).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = 1.0 / torch.sqrt(torch.tensor(self.d_k, dtype=torch.float32))
        attn = torch.matmul(q, k.transpose(-2, -1)) * scale
        attn = F.softmax(attn, dim=-1)
        attn = self.dropout(attn)
        
        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).reshape(B, T, C)
        out = self.out(out)
        return out

class AnglePredictionModel(nn.Module):
    def __init__(self, input_dim: int, d_model: int, n_heads: int, n_layers: int, dropout: float = 0.1):
        super().__init__()
        self.input_dim = input_dim
        self.d_model = d_model
        
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_encoding = nn.Parameter(torch.randn(1, 128, d_model) * 0.1)
        self.attn_layers = nn.ModuleList([
            FlashAttention(d_model, n_heads, dropout) for _ in range(n_layers)
        ])
        self.norm_layers = nn.ModuleList([
            nn.LayerNorm(d_model) for _ in range(n_layers)
        ])
        self.output = nn.Linear(d_model, 2)
        
        self.apply(self._init_weights)
    
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.xavier_uniform_(module.weight)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.input_proj(x)
        x = x + self.pos_encoding[:, :x.size(1), :]
        
        for attn, norm in zip(self.attn_layers, self.norm_layers):
            residual = x
            x = attn(x)
            x = norm(x + residual)
        
        x = x[:, -1, :]
        return self.output(x)

def train_model(model: nn.Module, train_loader: DataLoader, test_loader: DataLoader, 
                epochs: int, device: torch.device, lr: float = 1e-4):
    print("Model device:", next(model.parameters()).device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    scaler = torch.amp.GradScaler('cuda')
    criterion = nn.MSELoss()
    
    train_losses, test_losses = [], []
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for i, (batch_x, batch_y, _) in enumerate(train_loader):
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            if i == 0:
                print("Batch x device:", batch_x.device)
            
            optimizer.zero_grad()
            with torch.amp.autocast('cuda'):
                output = model(batch_x)
                if torch.isnan(output).any():
                    print(f"NaN in output at epoch {epoch+1}, batch {i}")
                    break
                loss = criterion(output, batch_y)
            
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y, _ in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                test_loss += criterion(output, batch_y).item()
        
        test_loss /= len(test_loader)
        test_losses.append(test_loss)
        
        scheduler.step()
        
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")
    
    return train_losses, test_losses

def plot_predictions(predictions: np.ndarray, actuals: np.ndarray, time_indices: np.ndarray, 
                     rmse_phi: float, rmse_theta: float, filename: str, title_prefix: str):
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, actuals[:, 0], label='Actual Phi (1551 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 0], label='Predicted Phi (from 1531 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Phi Time Series (RMSE: {rmse_phi:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Phi (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, actuals[:, 1], label='Actual Theta (1551 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 1], label='Predicted Theta (from 1531 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Theta Time Series (RMSE: {rmse_theta:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Theta (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()
    
    errors = np.abs(predictions - actuals)
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, errors[:, 0], label='|Predicted - Actual| Phi', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Phi Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, errors[:, 1], label='|Predicted - Actual| Theta', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Theta Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(f'errors_{filename.split("_", 1)[1]}')
    plt.close()

def experiment_window_sizes(data_path: str, window_sizes: list, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results = {}
    
    for window_size in window_sizes:
        print(f"\nExperimenting with window size: {window_size}")
        
        dataset_full = AngleDataset(data_path, window_size)
        total_length = len(dataset_full)
        train_length = int(0.8 * total_length)
        test_length = total_length - train_length
        
        train_indices = np.arange(train_length)
        test_indices = np.arange(train_length, total_length)
        
        train_dataset = AngleDataset(data_path, window_size, train_indices)
        test_dataset = AngleDataset(data_path, window_size, test_indices)
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=140,
            n_heads=4,
            n_layers=4,
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        time_indices = time_indices[sort_idx]
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        plot_predictions(
            predictions, actuals, time_indices, rmse_phi, rmse_theta,
            f'predictions_window_{window_size}.png',
            f'Window Size {window_size}'
        )
        
        results[window_size] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'model': model,
            'predictions': predictions,
            'actuals': actuals,
            'time_indices': time_indices,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Window Size: {window_size})')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_window_{window_size}.png')
        plt.close()
    
    plt.figure(figsize=(12, 6))
    for window_size, result in results.items():
        plt.plot(result['test_losses'], label=f'Window {window_size}')
    plt.title('Test Loss Comparison Across Window Sizes')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('window_size_comparison.png')
    plt.close()
    
    return results

def experiment_model_sizes(data_path: str, window_size: int = 64, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_configs = [
        {'name': 'small', 'd_model': 16, 'n_heads': 4, 'n_layers': 1},
        {'name': 'medium', 'd_model': 32, 'n_heads': 4, 'n_layers': 2},
        {'name': 'large', 'd_model': 64, 'n_heads': 8, 'n_layers': 3},
        # Extra Large: Increase d_model to ~140 to get ~5x parameters
        {'name': 'extra_large', 'd_model': 140, 'n_heads': 10, 'n_layers': 4}
    ]
    results = {}
    
    dataset_full = AngleDataset(data_path, window_size)
    total_length = len(dataset_full)
    train_length = int(0.8 * total_length)
    test_length = total_length - train_length

    train_indices = np.arange(train_length)
    test_indices = np.arange(train_length, total_length)

    train_dataset = AngleDataset(data_path, window_size, train_indices)
    test_dataset = AngleDataset(data_path, window_size, test_indices)

    rmse_phi_list = []
    rmse_theta_list = []
    model_names = []

    for config in model_configs:
        model_name = config['name']
        print(f"\nExperimenting with model size: {model_name} (d_model={config['d_model']}, "
              f"n_layers={config['n_layers']}, n_heads={config['n_heads']})")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=config['d_model'],
            n_heads=config['n_heads'],
            n_layers=config['n_layers'],
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        # Evaluation Phase
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        rmse_phi_list.append(rmse_phi)
        rmse_theta_list.append(rmse_theta)
        model_names.append(model_name.capitalize())
        
        # Existing plots
        plot_predictions(
            predictions, actuals, time_indices[sort_idx], rmse_phi, rmse_theta,
            f'predictions_model_{model_name}.png',
            f'Model {model_name.capitalize()} (Window Size {window_size})'
        )
        
        results[model_name] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }

        # Loss Curve Plot
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Model: {model_name}, Window Size: {window_size})')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_model_{model_name}.png')
        plt.close()
    
    # Plot RMSE Comparison Chart
    x = np.arange(len(model_names))
    width = 0.35

    plt.figure(figsize=(10, 6))
    plt.bar(x - width/2, rmse_phi_list, width, label='RMSE Phi')
    plt.bar(x + width/2, rmse_theta_list, width, label='RMSE Theta')
    plt.xticks(x, model_names)
    plt.ylabel('RMSE (degrees)')
    plt.title('RMSE Comparison Across Model Sizes')
    plt.legend()
    plt.grid(True, axis='y')
    plt.tight_layout()
    plt.savefig('rmse_model_comparison.png')
    plt.close()
    
    return results


if __name__ == "__main__":
    data_path = os.path.join("..", "Data", "data_angles", "data1_angles.csv")
    
    print("Attempting to access:", data_path)
    print("Full path:", os.path.abspath(data_path))
    if os.path.exists(data_path):
        print("File found!")
    else:
        print("File not found!")
        exit(1)
    
    # Experiment 1: Window sizes
    window_sizes = [8, 16, 32, 64, 128]
    window_results = experiment_window_sizes(data_path, window_sizes)
    
    # Experiment 2: Model sizes for window_size=64
    model_results = experiment_model_sizes(data_path, window_size=16)
# Out:
# Attempting to access: ..\Data\data_angles\data1_angles.csv
# Full path: C:\Users\Ely Eastman\Documents\polarization_stabilization_ml\Data\data_angles\data1_angles.csv
# File found!
#
# Experimenting with window size: 8
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0984, Test Loss: 0.1200
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0493, Test Loss: 0.0940
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0464, Test Loss: 0.1099
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0423, Test Loss: 0.0743
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0405, Test Loss: 0.0883
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0385, Test Loss: 0.0853
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0381, Test Loss: 0.0997
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0367, Test Loss: 0.0928
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0362, Test Loss: 0.0891
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0360, Test Loss: 0.1000
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0342, Test Loss: 0.1104
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0337, Test Loss: 0.0971
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0329, Test Loss: 0.0899
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0325, Test Loss: 0.0957
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0323, Test Loss: 0.0811
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0315, Test Loss: 0.1015
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0316, Test Loss: 0.0762
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0306, Test Loss: 0.0810
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0303, Test Loss: 0.0996
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0296, Test Loss: 0.0773
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0287, Test Loss: 0.0928
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0285, Test Loss: 0.0934
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0280, Test Loss: 0.0904
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0273, Test Loss: 0.0789
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0261, Test Loss: 0.0923
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0244, Test Loss: 0.0830
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0232, Test Loss: 0.0923
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0220, Test Loss: 0.0886
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0214, Test Loss: 0.0961
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0212, Test Loss: 0.1038
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0205, Test Loss: 0.1083
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0206, Test Loss: 0.0956
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0198, Test Loss: 0.0873
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0197, Test Loss: 0.1014
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0194, Test Loss: 0.0914
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0192, Test Loss: 0.1037
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0191, Test Loss: 0.0991
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0188, Test Loss: 0.0968
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0188, Test Loss: 0.0960
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0186, Test Loss: 0.1035
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0185, Test Loss: 0.1012
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0182, Test Loss: 0.0950
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0183, Test Loss: 0.1027
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0181, Test Loss: 0.0993
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0182, Test Loss: 0.0964
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0181, Test Loss: 0.0995
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0183, Test Loss: 0.1005
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0179, Test Loss: 0.0997
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0179, Test Loss: 0.0996
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0182, Test Loss: 0.0999
#
# Experimenting with window size: 16
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.1219, Test Loss: 0.1111
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0480, Test Loss: 0.0817
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0409, Test Loss: 0.0880
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0386, Test Loss: 0.0767
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0382, Test Loss: 0.0682
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0370, Test Loss: 0.1035
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0361, Test Loss: 0.0902
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0355, Test Loss: 0.0891
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0341, Test Loss: 0.0866
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0340, Test Loss: 0.0878
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0331, Test Loss: 0.0838
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0319, Test Loss: 0.0732
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0314, Test Loss: 0.1081
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0301, Test Loss: 0.1078
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0291, Test Loss: 0.0801
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0293, Test Loss: 0.0907
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0286, Test Loss: 0.0997
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0276, Test Loss: 0.0871
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0263, Test Loss: 0.1009
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0252, Test Loss: 0.0825
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0243, Test Loss: 0.0960
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0228, Test Loss: 0.0969
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0220, Test Loss: 0.1034
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0212, Test Loss: 0.1071
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0204, Test Loss: 0.1114
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0203, Test Loss: 0.1047
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0198, Test Loss: 0.1081
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0195, Test Loss: 0.1000
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0191, Test Loss: 0.1028
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0188, Test Loss: 0.0971
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0188, Test Loss: 0.1049
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0186, Test Loss: 0.1116
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0185, Test Loss: 0.1064
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0179, Test Loss: 0.1072
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0178, Test Loss: 0.1078
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0180, Test Loss: 0.1115
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0176, Test Loss: 0.1124
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0175, Test Loss: 0.1076
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0173, Test Loss: 0.1113
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0174, Test Loss: 0.1103
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0171, Test Loss: 0.1137
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0170, Test Loss: 0.1085
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0170, Test Loss: 0.1059
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0167, Test Loss: 0.1079
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0168, Test Loss: 0.1089
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0167, Test Loss: 0.1097
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0166, Test Loss: 0.1091
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0168, Test Loss: 0.1098
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0168, Test Loss: 0.1084
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0167, Test Loss: 0.1092
#
# Experimenting with window size: 32
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0693, Test Loss: 0.0743
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0463, Test Loss: 0.1084
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0434, Test Loss: 0.0792
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0411, Test Loss: 0.0840
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0390, Test Loss: 0.0908
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0374, Test Loss: 0.1581
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0376, Test Loss: 0.1150
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0360, Test Loss: 0.1186
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0356, Test Loss: 0.1154
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0348, Test Loss: 0.0966
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0335, Test Loss: 0.0973
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0330, Test Loss: 0.0800
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0322, Test Loss: 0.0982
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0312, Test Loss: 0.1002
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0305, Test Loss: 0.0919
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0297, Test Loss: 0.0925
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0285, Test Loss: 0.1083
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0285, Test Loss: 0.0538
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0271, Test Loss: 0.1085
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0265, Test Loss: 0.1008
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0249, Test Loss: 0.0974
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0248, Test Loss: 0.0887
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0238, Test Loss: 0.0768
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0233, Test Loss: 0.0841
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0232, Test Loss: 0.0828
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0224, Test Loss: 0.0791
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0224, Test Loss: 0.0769
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0219, Test Loss: 0.0838
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0217, Test Loss: 0.0942
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0215, Test Loss: 0.0838
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0210, Test Loss: 0.0819
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0211, Test Loss: 0.0766
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0209, Test Loss: 0.0825
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0207, Test Loss: 0.0808
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0205, Test Loss: 0.0877
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0200, Test Loss: 0.0953
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0200, Test Loss: 0.0886
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0199, Test Loss: 0.0906
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0198, Test Loss: 0.0830
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0197, Test Loss: 0.0808
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0194, Test Loss: 0.0908
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0193, Test Loss: 0.0896
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0192, Test Loss: 0.0909
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0194, Test Loss: 0.0891
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0193, Test Loss: 0.0917
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0189, Test Loss: 0.0899
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0190, Test Loss: 0.0891
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0190, Test Loss: 0.0892
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0189, Test Loss: 0.0880
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0190, Test Loss: 0.0882
#
# Experimenting with window size: 64
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0730, Test Loss: 0.1246
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0450, Test Loss: 0.0827
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0411, Test Loss: 0.1040
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0380, Test Loss: 0.0851
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0366, Test Loss: 0.1108
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0343, Test Loss: 0.1614
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0325, Test Loss: 0.1405
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0289, Test Loss: 0.1162
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0274, Test Loss: 0.1082
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0267, Test Loss: 0.0922
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0256, Test Loss: 0.0971
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0245, Test Loss: 0.1270
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0247, Test Loss: 0.0746
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0235, Test Loss: 0.0757
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0225, Test Loss: 0.0761
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0222, Test Loss: 0.0773
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0220, Test Loss: 0.0916
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0214, Test Loss: 0.0922
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0206, Test Loss: 0.0818
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0205, Test Loss: 0.0791
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0202, Test Loss: 0.0841
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0196, Test Loss: 0.0897
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0192, Test Loss: 0.0754
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0184, Test Loss: 0.0815
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0180, Test Loss: 0.0921
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0179, Test Loss: 0.0771
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0172, Test Loss: 0.0919
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0168, Test Loss: 0.0929
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0169, Test Loss: 0.0766
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0166, Test Loss: 0.0860
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0163, Test Loss: 0.0733
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0160, Test Loss: 0.0879
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0161, Test Loss: 0.0847
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0155, Test Loss: 0.0828
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0155, Test Loss: 0.0761
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0153, Test Loss: 0.0905
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0150, Test Loss: 0.0883
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0150, Test Loss: 0.0758
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0148, Test Loss: 0.0863
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0149, Test Loss: 0.0749
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0147, Test Loss: 0.0809
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0147, Test Loss: 0.0902
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0145, Test Loss: 0.0846
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0145, Test Loss: 0.0837
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0145, Test Loss: 0.0825
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0144, Test Loss: 0.0863
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0143, Test Loss: 0.0866
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0145, Test Loss: 0.0853
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0143, Test Loss: 0.0845
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0143, Test Loss: 0.0850
#
# Experimenting with window size: 128
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.1036, Test Loss: 0.0754
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0442, Test Loss: 0.0775
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0375, Test Loss: 0.0695
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0339, Test Loss: 0.0885
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0298, Test Loss: 0.0930
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0271, Test Loss: 0.0932
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0245, Test Loss: 0.0990
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0229, Test Loss: 0.1063
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0217, Test Loss: 0.0802
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0206, Test Loss: 0.0807
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0196, Test Loss: 0.0828
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0182, Test Loss: 0.0899
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0184, Test Loss: 0.0418
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0181, Test Loss: 0.1100
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0170, Test Loss: 0.1014
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0163, Test Loss: 0.0826
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0161, Test Loss: 0.0722
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0161, Test Loss: 0.0785
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0158, Test Loss: 0.0894
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0156, Test Loss: 0.0798
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0148, Test Loss: 0.1053
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0149, Test Loss: 0.0823
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0147, Test Loss: 0.0823
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0140, Test Loss: 0.0941
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0138, Test Loss: 0.1100
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0137, Test Loss: 0.1177
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0130, Test Loss: 0.1031
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0128, Test Loss: 0.0912
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0125, Test Loss: 0.1033
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0123, Test Loss: 0.0901
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0121, Test Loss: 0.1017
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0118, Test Loss: 0.0949
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0114, Test Loss: 0.1015
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0114, Test Loss: 0.0965
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0111, Test Loss: 0.0919
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0110, Test Loss: 0.1039
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0108, Test Loss: 0.0956
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0106, Test Loss: 0.0908
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0105, Test Loss: 0.0915
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0105, Test Loss: 0.0976
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0103, Test Loss: 0.0964
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0102, Test Loss: 0.1007
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0101, Test Loss: 0.1023
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0099, Test Loss: 0.0996
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0099, Test Loss: 0.0988
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0099, Test Loss: 0.0954
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0098, Test Loss: 0.0958
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0098, Test Loss: 0.0963
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0098, Test Loss: 0.0969
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0099, Test Loss: 0.0966
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
# Normalized Feature Phi range: -0.9990245738912378 to 0.9996774504787057
# Normalized Feature Theta range: 0.1473259301257695 to 0.8428363908826839
# Normalized Target Phi range: -0.9727824167538099 to 0.9961645673765517
# Normalized Target Theta range: 0.2620906844265113 to 0.9977737740563682
#
# Experimenting with model size: small (d_model=16, n_layers=1, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.3046, Test Loss: 0.0946
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0599, Test Loss: 0.0744
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0510, Test Loss: 0.0807
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0487, Test Loss: 0.0754
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0478, Test Loss: 0.0796
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0469, Test Loss: 0.0828
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0463, Test Loss: 0.0810
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0459, Test Loss: 0.0787
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0453, Test Loss: 0.0777
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0450, Test Loss: 0.0865
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0446, Test Loss: 0.0805
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0444, Test Loss: 0.0832
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0445, Test Loss: 0.0764
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0441, Test Loss: 0.0820
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0438, Test Loss: 0.0855
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0440, Test Loss: 0.0877
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0439, Test Loss: 0.0787
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0436, Test Loss: 0.0859
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0437, Test Loss: 0.0831
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0435, Test Loss: 0.0826
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0434, Test Loss: 0.0849
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0431, Test Loss: 0.0838
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0431, Test Loss: 0.0869
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0431, Test Loss: 0.0829
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0430, Test Loss: 0.0886
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0431, Test Loss: 0.0840
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0430, Test Loss: 0.0805
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0428, Test Loss: 0.0831
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0429, Test Loss: 0.0820
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0429, Test Loss: 0.0831
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0428, Test Loss: 0.0781
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0428, Test Loss: 0.0812
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0428, Test Loss: 0.0833
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0427, Test Loss: 0.0822
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0428, Test Loss: 0.0821
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0427, Test Loss: 0.0838
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0427, Test Loss: 0.0839
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0425, Test Loss: 0.0846
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0428, Test Loss: 0.0832
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0426, Test Loss: 0.0857
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0427, Test Loss: 0.0849
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0426, Test Loss: 0.0849
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0427, Test Loss: 0.0842
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0426, Test Loss: 0.0852
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0426, Test Loss: 0.0848
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0424, Test Loss: 0.0847
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0426, Test Loss: 0.0848
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0425, Test Loss: 0.0848
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0427, Test Loss: 0.0848
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0427, Test Loss: 0.0848
#
# Experimenting with model size: medium (d_model=32, n_layers=2, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.1266, Test Loss: 0.1033
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0576, Test Loss: 0.0826
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0521, Test Loss: 0.0925
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0486, Test Loss: 0.0791
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0470, Test Loss: 0.0794
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0461, Test Loss: 0.0806
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0454, Test Loss: 0.0725
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0443, Test Loss: 0.0757
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0436, Test Loss: 0.0860
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0436, Test Loss: 0.0808
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0429, Test Loss: 0.0872
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0427, Test Loss: 0.0765
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0421, Test Loss: 0.0910
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0418, Test Loss: 0.0867
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0413, Test Loss: 0.0841
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0407, Test Loss: 0.0833
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0402, Test Loss: 0.0837
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0398, Test Loss: 0.0864
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0393, Test Loss: 0.0960
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0392, Test Loss: 0.0829
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0390, Test Loss: 0.0824
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0387, Test Loss: 0.0866
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0382, Test Loss: 0.0847
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0381, Test Loss: 0.0845
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0378, Test Loss: 0.0888
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0374, Test Loss: 0.0889
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0373, Test Loss: 0.0898
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0370, Test Loss: 0.0862
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0368, Test Loss: 0.0897
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0367, Test Loss: 0.0841
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0365, Test Loss: 0.0872
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0365, Test Loss: 0.0861
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0363, Test Loss: 0.0844
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0363, Test Loss: 0.0918
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0362, Test Loss: 0.0883
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0358, Test Loss: 0.0858
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0358, Test Loss: 0.0881
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0357, Test Loss: 0.0896
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0359, Test Loss: 0.0874
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0356, Test Loss: 0.0852
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0358, Test Loss: 0.0862
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0356, Test Loss: 0.0885
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0357, Test Loss: 0.0887
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0356, Test Loss: 0.0842
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0354, Test Loss: 0.0867
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0354, Test Loss: 0.0850
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0354, Test Loss: 0.0860
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0357, Test Loss: 0.0860
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0354, Test Loss: 0.0860
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0356, Test Loss: 0.0862
#
# Experimenting with model size: large (d_model=64, n_layers=3, n_heads=8)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.0891, Test Loss: 0.0759
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0492, Test Loss: 0.1055
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0455, Test Loss: 0.0919
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0441, Test Loss: 0.0745
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0422, Test Loss: 0.1023
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0402, Test Loss: 0.0724
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0385, Test Loss: 0.0874
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0374, Test Loss: 0.0964
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0370, Test Loss: 0.0836
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0364, Test Loss: 0.1092
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0361, Test Loss: 0.1147
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0360, Test Loss: 0.0918
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0354, Test Loss: 0.0959
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0350, Test Loss: 0.0800
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0346, Test Loss: 0.0929
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0340, Test Loss: 0.0920
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0338, Test Loss: 0.1027
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0335, Test Loss: 0.0957
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0331, Test Loss: 0.0945
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0326, Test Loss: 0.1100
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0322, Test Loss: 0.0983
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0320, Test Loss: 0.0974
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0316, Test Loss: 0.1001
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0315, Test Loss: 0.1032
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0313, Test Loss: 0.0965
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0312, Test Loss: 0.1008
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0308, Test Loss: 0.0947
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0305, Test Loss: 0.0969
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0307, Test Loss: 0.1010
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0305, Test Loss: 0.0960
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0304, Test Loss: 0.0957
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0301, Test Loss: 0.0913
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0301, Test Loss: 0.0823
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0301, Test Loss: 0.0929
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0299, Test Loss: 0.0961
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0299, Test Loss: 0.0879
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0298, Test Loss: 0.0914
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0297, Test Loss: 0.1053
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0296, Test Loss: 0.0926
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0296, Test Loss: 0.0945
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0297, Test Loss: 0.0940
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0296, Test Loss: 0.0950
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0294, Test Loss: 0.0887
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0293, Test Loss: 0.0904
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0293, Test Loss: 0.0941
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0292, Test Loss: 0.0943
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0293, Test Loss: 0.0939
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0294, Test Loss: 0.0939
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0294, Test Loss: 0.0929
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0292, Test Loss: 0.0930
#
# Experimenting with model size: extra_large (d_model=140, n_layers=4, n_heads=10)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.1444, Test Loss: 0.1060
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.0470, Test Loss: 0.1228
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0435, Test Loss: 0.0761
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0401, Test Loss: 0.0822
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0397, Test Loss: 0.0824
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0377, Test Loss: 0.1128
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0369, Test Loss: 0.0753
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0365, Test Loss: 0.0840
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0350, Test Loss: 0.1024
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0348, Test Loss: 0.1108
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0338, Test Loss: 0.1127
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0333, Test Loss: 0.0789
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0328, Test Loss: 0.0863
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0321, Test Loss: 0.0871
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0311, Test Loss: 0.1089
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0302, Test Loss: 0.0805
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0297, Test Loss: 0.0844
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0292, Test Loss: 0.0871
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0293, Test Loss: 0.0864
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0289, Test Loss: 0.0835
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0288, Test Loss: 0.1036
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0282, Test Loss: 0.0893
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0283, Test Loss: 0.0926
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0280, Test Loss: 0.0981
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0278, Test Loss: 0.0756
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0274, Test Loss: 0.0930
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0273, Test Loss: 0.0916
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0274, Test Loss: 0.0717
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0272, Test Loss: 0.0814
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0269, Test Loss: 0.0913
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0269, Test Loss: 0.0869
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0269, Test Loss: 0.0848
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0266, Test Loss: 0.0856
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0265, Test Loss: 0.0916
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0264, Test Loss: 0.0854
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0263, Test Loss: 0.0924
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0266, Test Loss: 0.0855
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0264, Test Loss: 0.0922
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0261, Test Loss: 0.0882
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0259, Test Loss: 0.0890
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0259, Test Loss: 0.0866
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0259, Test Loss: 0.0928
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0259, Test Loss: 0.0897
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0258, Test Loss: 0.0909
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0258, Test Loss: 0.0878
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0258, Test Loss: 0.0892
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0256, Test Loss: 0.0906
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0255, Test Loss: 0.0893
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0256, Test Loss: 0.0895
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0256, Test Loss: 0.0896

# %%
type(model_results)
# Out:
# dict

# %%
model_results.keys()
# Out:
# dict_keys(['small', 'medium', 'large', 'extra_large'])

# %%
model_results.values()
# Out:
# dict_values([{'train_losses': [0.3046268061284096, 0.059922470320617, 0.050961285408946774, 0.04874727024357715, 0.047820143178448696, 0.04685221828760639, 0.04628581955410918, 0.045867144761066285, 0.045256047316479246, 0.044980418992825365, 0.04464713978465252, 0.04439954973825936, 0.04450364913018892, 0.04412431441556473, 0.04382363696526822, 0.04395231777106837, 0.04385914647531125, 0.043566210701855644, 0.043666298170724226, 0.04347203850471479, 0.043379977620142396, 0.043147739709659655, 0.04314233407309528, 0.04306119988556557, 0.04300235187815082, 0.043051512602905524, 0.04300821007740113, 0.04278913753167275, 0.04285919325520641, 0.04290605048876479, 0.04278279820345514, 0.042778160749217885, 0.04281611182653959, 0.04273255789987228, 0.04277592694841772, 0.0426725155249032, 0.042697470120158613, 0.04249512955271703, 0.042754136952936374, 0.04257642683757615, 0.04268607945280141, 0.04259936221390276, 0.04268081143738762, 0.042598370505574114, 0.04259681360890514, 0.04244740666126326, 0.04261505423534301, 0.04251780502566819, 0.04266790711762993, 0.04267326936400431], 'test_losses': [0.09455564706162974, 0.07439843074164608, 0.08066156608137218, 0.07536680095575073, 0.07957974645224485, 0.08282775983891703, 0.08101573173295368, 0.07865754457359964, 0.07766253264112906, 0.08647888292643156, 0.08049548241225156, 0.08316671858457002, 0.07644472406669096, 0.08195252367718653, 0.08553329055959528, 0.08768563135103746, 0.07870826575566423, 0.0858706433326006, 0.08308296833526005, 0.08259975005957214, 0.08491176634349606, 0.08380818712440403, 0.08694675392047925, 0.08287261175838384, 0.08864676874469626, 0.08396939923140136, 0.08052545975555073, 0.08305611749264327, 0.08204832398755983, 0.0831246520307931, 0.0781301378526471, 0.0811986475505612, 0.08334453793411906, 0.08222183348103003, 0.08208430636335504, 0.08384793898598715, 0.08386256325651299, 0.08459118591113524, 0.08317967368797823, 0.08572045141323047, 0.08492238304831765, 0.08488302366300063, 0.08415380489419808, 0.08523233858021823, 0.08484251346777785, 0.08471473313190721, 0.08482540808618069, 0.08481601899997755, 0.08482102358883077, 0.08483356193385341], 'rmse_phi': 64.23965, 'rmse_theta': 36.80852}, {'train_losses': [0.12663100152555423, 0.057605115456446525, 0.05211701609777965, 0.048632526881821146, 0.04697327320957514, 0.0460777704943023, 0.04539538875290875, 0.044340350420518954, 0.043646272632383534, 0.043573540957292656, 0.04292919855856676, 0.042745148591388206, 0.04214165735697966, 0.04183383007031707, 0.04132456550469047, 0.04066448189180842, 0.040225716324926525, 0.03975617901898474, 0.03933843280175864, 0.03916782533861525, 0.0390187233240099, 0.03870998662874995, 0.03820491135807081, 0.03813052344809754, 0.03778751062289361, 0.03744811333784585, 0.037267207112249144, 0.03697606077426315, 0.03679026059875016, 0.03674061771499396, 0.03647974803872098, 0.036545951769167924, 0.03627739710226861, 0.036274851973636356, 0.03617409352333315, 0.03582880082905018, 0.03581740175833076, 0.035731919573336705, 0.03585512027110098, 0.03562112985187412, 0.03582450595559887, 0.0356202193274064, 0.0356577340307461, 0.03564261197872151, 0.035429717526526495, 0.03538431905313021, 0.035377815056781066, 0.03565964379137562, 0.035449055800308826, 0.035592798684393204], 'test_losses': [0.10334459311244162, 0.0826009753075513, 0.09249127795073118, 0.0790571042759852, 0.07935558452524923, 0.08063266296786341, 0.07247234051200477, 0.07571057491004467, 0.08597020276568153, 0.0807682312686335, 0.08721841638061133, 0.07645283624191176, 0.0910193514756181, 0.08668275378983128, 0.084058129042387, 0.08332978681745855, 0.0836865279992873, 0.08644512476907536, 0.0959975390271707, 0.08288999155841091, 0.08244062909348444, 0.08659307943149046, 0.08465033182027665, 0.08450523958626119, 0.08880526230416515, 0.08890102641149, 0.08977732135152275, 0.08623864765871656, 0.08974441015584902, 0.0841052065349438, 0.08722816041924737, 0.08607296704907309, 0.08443226651711898, 0.0918486209755594, 0 ...
