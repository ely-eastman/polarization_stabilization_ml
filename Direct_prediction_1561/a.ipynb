# %%
import os
data_path = "../Data/data_angles/data7_angles.csv"
print("Attempting to access:", data_path)
print("Full path:", os.path.abspath(data_path))
if os.path.exists(data_path):
    print("File found!")
else:
    print("File not found!")
# Out:
# Attempting to access: ../Data/data_angles/data7_angles.csv
# Full path: /home/exx/Desktop/quantum/Data/data_angles/data7_angles.csv
# File found!

# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import GradScaler, autocast
import matplotlib.pyplot as plt
from typing import Tuple

# Verify GPU
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("GPU count:", torch.cuda.device_count())
    print("GPU name:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected, exiting!")
    exit(1)

class AngleDataset(Dataset):
    def __init__(self, data_path: str, window_size: int, indices: np.ndarray = None):
        self.df = pd.read_csv(data_path)
        if self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                   'Target Phi (degrees)', 'Target Theta (degrees)']].isna().any().any():
            print("Warning: NaN values found in data!")
            self.df = self.df.dropna()
        if np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                            'Target Phi (degrees)', 'Target Theta (degrees)']].values).any():
            print("Warning: Infinite values found in data!")
            self.df = self.df[~np.isinf(self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)', 
                                                'Target Phi (degrees)', 'Target Theta (degrees)']]).any(axis=1)]
        
        self.features = self.df[['Feature Phi (degrees)', 'Feature Theta (degrees)']].values
        self.targets = self.df[['Target Phi (degrees)', 'Target Theta (degrees)']].values
        self.features[:, 0] /= 180.0
        self.features[:, 1] /= 180.0
        self.targets[:, 0] /= 180.0
        self.targets[:, 1] /= 180.0
        
        print("Normalized Feature Phi range:", self.features[:, 0].min(), "to", self.features[:, 0].max())
        print("Normalized Feature Theta range:", self.features[:, 1].min(), "to", self.features[:, 1].max())
        print("Normalized Target Phi range:", self.targets[:, 0].min(), "to", self.targets[:, 0].max())
        print("Normalized Target Theta range:", self.targets[:, 1].min(), "to", self.targets[:, 1].max())
        
        self.window_size = window_size
        self.indices = indices if indices is not None else np.arange(len(self.df) - window_size + 1)
        self.length = len(self.indices)

    def __len__(self) -> int:
        return self.length

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor, int]:
        data_idx = self.indices[idx]
        window = self.features[data_idx:data_idx + self.window_size]
        target = self.targets[data_idx + self.window_size - 1]
        time_index = data_idx + self.window_size - 1
        return torch.FloatTensor(window), torch.FloatTensor(target), time_index

class FlashAttention(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.1):
        super().__init__()
        assert d_model % n_heads == 0, "d_model must be divisible by n_heads"
        self.d_model = d_model
        self.n_heads = n_heads
        self.d_k = d_model // n_heads
        self.dropout = nn.Dropout(dropout)
        
        self.qkv = nn.Linear(d_model, 3 * d_model)
        self.out = nn.Linear(d_model, d_model)
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        B, T, C = x.shape
        qkv = self.qkv(x).reshape(B, T, 3, self.n_heads, self.d_k).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        
        scale = 1.0 / torch.sqrt(torch.tensor(self.d_k, dtype=torch.float32))
        attn = torch.matmul(q, k.transpose(-2, -1)) * scale
        attn = F.softmax(attn, dim=-1)
        attn = self.dropout(attn)
        
        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).reshape(B, T, C)
        out = self.out(out)
        return out

class AnglePredictionModel(nn.Module):
    def __init__(self, input_dim: int, d_model: int, n_heads: int, n_layers: int, dropout: float = 0.1):
        super().__init__()
        self.input_dim = input_dim
        self.d_model = d_model
        
        self.input_proj = nn.Linear(input_dim, d_model)
        self.pos_encoding = nn.Parameter(torch.randn(1, 128, d_model) * 0.1)
        self.attn_layers = nn.ModuleList([
            FlashAttention(d_model, n_heads, dropout) for _ in range(n_layers)
        ])
        self.norm_layers = nn.ModuleList([
            nn.LayerNorm(d_model) for _ in range(n_layers)
        ])
        self.output = nn.Linear(d_model, 2)
        
        self.apply(self._init_weights)
    
    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.xavier_uniform_(module.weight)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.input_proj(x)
        x = x + self.pos_encoding[:, :x.size(1), :]
        
        for attn, norm in zip(self.attn_layers, self.norm_layers):
            residual = x
            x = attn(x)
            x = norm(x + residual)
        
        x = x[:, -1, :]
        return self.output(x)

def train_model(model: nn.Module, train_loader: DataLoader, test_loader: DataLoader, 
                epochs: int, device: torch.device, lr: float = 1e-4):
    print("Model device:", next(model.parameters()).device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    scaler = torch.amp.GradScaler('cuda')
    criterion = nn.MSELoss()
    
    train_losses, test_losses = [], []
    
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for i, (batch_x, batch_y, _) in enumerate(train_loader):
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            if i == 0:
                print("Batch x device:", batch_x.device)
            
            optimizer.zero_grad()
            with torch.amp.autocast('cuda'):
                output = model(batch_x)
                if torch.isnan(output).any():
                    print(f"NaN in output at epoch {epoch+1}, batch {i}")
                    break
                loss = criterion(output, batch_y)
            
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            scaler.step(optimizer)
            scaler.update()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y, _ in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                test_loss += criterion(output, batch_y).item()
        
        test_loss /= len(test_loader)
        test_losses.append(test_loss)
        
        scheduler.step()
        
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}")
    
    return train_losses, test_losses

def plot_predictions(predictions: np.ndarray, actuals: np.ndarray, time_indices: np.ndarray, 
                     rmse_phi: float, rmse_theta: float, filename: str, title_prefix: str):
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, actuals[:, 0], label='Actual Phi (1551 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 0], label='Predicted Phi (from 1550 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Phi Time Series (RMSE: {rmse_phi:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Phi (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, actuals[:, 1], label='Actual Theta (1551 nm, °)', color='blue', linewidth=2)
    plt.plot(time_indices, predictions[:, 1], label='Predicted Theta (from 1550 nm, °)', color='red', linestyle='--', linewidth=2)
    plt.title(f'{title_prefix} Theta Time Series (RMSE: {rmse_theta:.2f}°)')
    plt.xlabel('Time Index')
    plt.ylabel('Theta (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(filename)
    plt.close()
    
    errors = np.abs(predictions - actuals)
    plt.figure(figsize=(12, 8))
    
    plt.subplot(2, 1, 1)
    plt.plot(time_indices, errors[:, 0], label='|Predicted - Actual| Phi', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Phi Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(time_indices, errors[:, 1], label='|Predicted - Actual| Theta', color='purple', linewidth=2)
    plt.title(f'{title_prefix} Theta Absolute Error')
    plt.xlabel('Time Index')
    plt.ylabel('Error (degrees)')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(f'errors_{filename.split("_", 1)[1]}')
    plt.close()

def experiment_window_sizes(data_path: str, window_sizes: list, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results = {}
    
    for window_size in window_sizes:
        print(f"\nExperimenting with window size: {window_size}")
        
        dataset_full = AngleDataset(data_path, window_size)
        total_length = len(dataset_full)
        train_length = int(0.8 * total_length)
        test_length = total_length - train_length
        
        train_indices = np.arange(train_length)
        test_indices = np.arange(train_length, total_length)
        
        train_dataset = AngleDataset(data_path, window_size, train_indices)
        test_dataset = AngleDataset(data_path, window_size, test_indices)
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=32,
            n_heads=4,
            n_layers=2,
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        time_indices = time_indices[sort_idx]
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        plot_predictions(
            predictions, actuals, time_indices, rmse_phi, rmse_theta,
            f'predictions_window_{window_size}.png',
            f'Window Size {window_size}'
        )
        
        results[window_size] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'model': model,
            'predictions': predictions,
            'actuals': actuals,
            'time_indices': time_indices,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Window Size: {window_size})')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_window_{window_size}.png')
        plt.close()
    
    plt.figure(figsize=(12, 6))
    for window_size, result in results.items():
        plt.plot(result['test_losses'], label=f'Window {window_size}')
    plt.title('Test Loss Comparison Across Window Sizes')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('window_size_comparison.png')
    plt.close()
    
    return results

def experiment_model_sizes(data_path: str, window_size: int = 64, batch_size: int = 64, epochs: int = 50):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model_configs = [
        {'name': 'small', 'd_model': 16, 'n_heads': 4, 'n_layers': 1},
        {'name': 'medium', 'd_model': 32, 'n_heads': 4, 'n_layers': 2},
        {'name': 'large', 'd_model': 64, 'n_heads': 8, 'n_layers': 3}
    ]
    results = {}
    
    dataset_full = AngleDataset(data_path, window_size)
    total_length = len(dataset_full)
    train_length = int(0.8 * total_length)
    test_length = total_length - train_length
    
    train_indices = np.arange(train_length)
    test_indices = np.arange(train_length, total_length)
    
    train_dataset = AngleDataset(data_path, window_size, train_indices)
    test_dataset = AngleDataset(data_path, window_size, test_indices)
    
    for config in model_configs:
        model_name = config['name']
        print(f"\nExperimenting with model size: {model_name} (d_model={config['d_model']}, "
              f"n_layers={config['n_layers']}, n_heads={config['n_heads']})")
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        model = AnglePredictionModel(
            input_dim=2,
            d_model=config['d_model'],
            n_heads=config['n_heads'],
            n_layers=config['n_layers'],
            dropout=0.1
        ).to(device)
        
        train_losses, test_losses = train_model(
            model, train_loader, test_loader, epochs, device
        )
        
        model.eval()
        predictions = []
        actuals = []
        time_indices = []
        with torch.no_grad():
            for batch_x, batch_y, batch_indices in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                with torch.amp.autocast('cuda'):
                    output = model(batch_x)
                output = output.cpu().numpy() * 180.0
                batch_y = batch_y.cpu().numpy() * 180.0
                predictions.append(output)
                actuals.append(batch_y)
                time_indices.append(batch_indices.numpy())
        
        predictions = np.concatenate(predictions, axis=0)
        actuals = np.concatenate(actuals, axis=0)
        time_indices = np.concatenate(time_indices, axis=0)
        
        sort_idx = np.argsort(time_indices)
        time_indices = time_indices[sort_idx]
        predictions = predictions[sort_idx]
        actuals = actuals[sort_idx]
        
        rmse_phi = np.sqrt(np.mean((predictions[:, 0] - actuals[:, 0])**2))
        rmse_theta = np.sqrt(np.mean((predictions[:, 1] - actuals[:, 1])**2))
        
        plot_predictions(
            predictions, actuals, time_indices, rmse_phi, rmse_theta,
            f'predictions_model_{model_name}.png',
            f'Model {model_name.capitalize()} (Window Size 64)'
        )
        
        results[model_name] = {
            'train_losses': train_losses,
            'test_losses': test_losses,
            'model': model,
            'predictions': predictions,
            'actuals': actuals,
            'time_indices': time_indices,
            'rmse_phi': rmse_phi,
            'rmse_theta': rmse_theta
        }
        
        plt.figure(figsize=(10, 5))
        plt.plot(train_losses, label='Train Loss')
        plt.plot(test_losses, label='Test Loss')
        plt.title(f'Loss Curves (Model: {model_name}, Window Size: 64)')
        plt.xlabel('Epoch')
        plt.ylabel('MSE Loss')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'loss_model_{model_name}.png')
        plt.close()
    
    plt.figure(figsize=(12, 6))
    for model_name, result in results.items():
        plt.plot(result['test_losses'], label=f'Model {model_name}')
    plt.title('Test Loss Comparison Across Model Sizes (Window Size: 64)')
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True)
    plt.savefig('model_size_comparison_window_64.png')
    plt.close()
    
    return results

if __name__ == "__main__":
    data_path = os.path.join("..", "Data", "data_angles", "data7_angles.csv")
    
    print("Attempting to access:", data_path)
    print("Full path:", os.path.abspath(data_path))
    if os.path.exists(data_path):
        print("File found!")
    else:
        print("File not found!")
        exit(1)
    
    # Experiment 1: Window sizes
    window_sizes = [8, 16, 32, 64, 128]
    window_results = experiment_window_sizes(data_path, window_sizes)
    
    # Experiment 2: Model sizes for window_size=64
    model_results = experiment_model_sizes(data_path, window_size=64)
# Out:
# PyTorch version: 2.5.1
# CUDA available: True
# CUDA version: 12.4
# GPU count: 1
# GPU name: NVIDIA H100 NVL
# Attempting to access: ../Data/data_angles/data6_angles.csv
# Full path: /home/exx/Desktop/quantum/Data/data_angles/data6_angles.csv
# File found!
#
# Experimenting with window size: 8
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.6093, Test Loss: 0.1028
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1347, Test Loss: 0.0670
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1011, Test Loss: 0.0488
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0842, Test Loss: 0.0406
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0767, Test Loss: 0.0367
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0723, Test Loss: 0.0340
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0685, Test Loss: 0.0330
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0654, Test Loss: 0.0323
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0634, Test Loss: 0.0314
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0611, Test Loss: 0.0302
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0585, Test Loss: 0.0305
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0577, Test Loss: 0.0285
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0553, Test Loss: 0.0285
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0521, Test Loss: 0.0273
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0495, Test Loss: 0.0250
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0480, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0452, Test Loss: 0.0221
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0433, Test Loss: 0.0219
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0403, Test Loss: 0.0204
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0393, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0385, Test Loss: 0.0214
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0366, Test Loss: 0.0197
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0353, Test Loss: 0.0186
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0354, Test Loss: 0.0188
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0344, Test Loss: 0.0206
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0349, Test Loss: 0.0189
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0342, Test Loss: 0.0193
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0336, Test Loss: 0.0187
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0333, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0329, Test Loss: 0.0194
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0334, Test Loss: 0.0181
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0329, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0331, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0326, Test Loss: 0.0186
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0330, Test Loss: 0.0188
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0326, Test Loss: 0.0179
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0321, Test Loss: 0.0181
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0320, Test Loss: 0.0186
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0316, Test Loss: 0.0184
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0318, Test Loss: 0.0181
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0314, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0323, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0318, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0317, Test Loss: 0.0183
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0319, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0315, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0316, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0317, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0309, Test Loss: 0.0182
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0318, Test Loss: 0.0182
#
# Experimenting with window size: 16
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.4684, Test Loss: 0.1181
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1264, Test Loss: 0.0832
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1030, Test Loss: 0.0681
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0891, Test Loss: 0.0583
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0820, Test Loss: 0.0457
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0756, Test Loss: 0.0406
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0704, Test Loss: 0.0379
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0677, Test Loss: 0.0353
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0640, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0618, Test Loss: 0.0314
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0594, Test Loss: 0.0300
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0569, Test Loss: 0.0293
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0547, Test Loss: 0.0293
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0525, Test Loss: 0.0280
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0509, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0486, Test Loss: 0.0280
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0475, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0455, Test Loss: 0.0286
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0442, Test Loss: 0.0283
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0424, Test Loss: 0.0270
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0410, Test Loss: 0.0274
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0418, Test Loss: 0.0269
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0390, Test Loss: 0.0271
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0388, Test Loss: 0.0269
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0384, Test Loss: 0.0268
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0378, Test Loss: 0.0265
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0371, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0365, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0358, Test Loss: 0.0271
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0355, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0358, Test Loss: 0.0257
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0367, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0343, Test Loss: 0.0259
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0346, Test Loss: 0.0257
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0343, Test Loss: 0.0259
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0337, Test Loss: 0.0256
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0343, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0341, Test Loss: 0.0256
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0333, Test Loss: 0.0256
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0342, Test Loss: 0.0253
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0325, Test Loss: 0.0258
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0329, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0331, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0333, Test Loss: 0.0255
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0330, Test Loss: 0.0256
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0335, Test Loss: 0.0254
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0332, Test Loss: 0.0254
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0334, Test Loss: 0.0254
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0331, Test Loss: 0.0254
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0334, Test Loss: 0.0254
#
# Experimenting with window size: 32
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.4815, Test Loss: 0.1089
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1183, Test Loss: 0.0761
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0913, Test Loss: 0.0611
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0817, Test Loss: 0.0504
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0746, Test Loss: 0.0404
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0710, Test Loss: 0.0400
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0684, Test Loss: 0.0382
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0661, Test Loss: 0.0419
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0640, Test Loss: 0.0365
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0621, Test Loss: 0.0355
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0594, Test Loss: 0.0354
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0576, Test Loss: 0.0356
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0562, Test Loss: 0.0353
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0534, Test Loss: 0.0346
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0528, Test Loss: 0.0347
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0513, Test Loss: 0.0339
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0491, Test Loss: 0.0339
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0466, Test Loss: 0.0336
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0453, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0441, Test Loss: 0.0315
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0419, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0414, Test Loss: 0.0316
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0398, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0389, Test Loss: 0.0307
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0380, Test Loss: 0.0291
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0375, Test Loss: 0.0281
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0361, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0353, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0350, Test Loss: 0.0279
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0350, Test Loss: 0.0278
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0343, Test Loss: 0.0273
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0341, Test Loss: 0.0271
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0340, Test Loss: 0.0268
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0333, Test Loss: 0.0265
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0329, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0326, Test Loss: 0.0266
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0322, Test Loss: 0.0264
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0317, Test Loss: 0.0265
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0321, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0310, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0312, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0315, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0314, Test Loss: 0.0262
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0316, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0311, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0313, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0311, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0309, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0312, Test Loss: 0.0261
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0309, Test Loss: 0.0261
#
# Experimenting with window size: 64
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.9081, Test Loss: 0.1990
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1816, Test Loss: 0.1232
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1402, Test Loss: 0.1075
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.1180, Test Loss: 0.0959
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.1037, Test Loss: 0.0852
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0944, Test Loss: 0.0725
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0877, Test Loss: 0.0616
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0816, Test Loss: 0.0544
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0779, Test Loss: 0.0511
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0739, Test Loss: 0.0469
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0720, Test Loss: 0.0458
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0690, Test Loss: 0.0426
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0672, Test Loss: 0.0417
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0649, Test Loss: 0.0403
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0635, Test Loss: 0.0391
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0613, Test Loss: 0.0382
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0591, Test Loss: 0.0369
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0579, Test Loss: 0.0363
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0558, Test Loss: 0.0353
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0542, Test Loss: 0.0344
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0529, Test Loss: 0.0348
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0519, Test Loss: 0.0348
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0505, Test Loss: 0.0339
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0498, Test Loss: 0.0335
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0487, Test Loss: 0.0335
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0475, Test Loss: 0.0334
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0468, Test Loss: 0.0335
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0461, Test Loss: 0.0329
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0455, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0448, Test Loss: 0.0323
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0443, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0437, Test Loss: 0.0318
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0431, Test Loss: 0.0318
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0429, Test Loss: 0.0320
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0421, Test Loss: 0.0317
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0420, Test Loss: 0.0311
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0410, Test Loss: 0.0313
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0417, Test Loss: 0.0311
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0413, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0408, Test Loss: 0.0307
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0406, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0407, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0407, Test Loss: 0.0307
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0403, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0406, Test Loss: 0.0305
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0400, Test Loss: 0.0304
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0403, Test Loss: 0.0305
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0401, Test Loss: 0.0305
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0401, Test Loss: 0.0305
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0401, Test Loss: 0.0305
#
# Experimenting with window size: 128
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.7804, Test Loss: 0.2375
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.2119, Test Loss: 0.1482
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1664, Test Loss: 0.1114
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.1363, Test Loss: 0.0981
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.1119, Test Loss: 0.0957
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0967, Test Loss: 0.0858
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0877, Test Loss: 0.0944
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0817, Test Loss: 0.0689
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0772, Test Loss: 0.0674
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0732, Test Loss: 0.0555
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0696, Test Loss: 0.0530
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0666, Test Loss: 0.0478
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0637, Test Loss: 0.0457
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0619, Test Loss: 0.0435
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0598, Test Loss: 0.0443
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0580, Test Loss: 0.0398
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0556, Test Loss: 0.0417
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0544, Test Loss: 0.0377
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0522, Test Loss: 0.0380
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0515, Test Loss: 0.0362
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0500, Test Loss: 0.0350
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0490, Test Loss: 0.0353
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0479, Test Loss: 0.0341
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0468, Test Loss: 0.0339
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0463, Test Loss: 0.0325
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0454, Test Loss: 0.0326
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0447, Test Loss: 0.0324
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0442, Test Loss: 0.0318
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0434, Test Loss: 0.0315
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0424, Test Loss: 0.0311
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0424, Test Loss: 0.0314
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0416, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0413, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0406, Test Loss: 0.0305
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0407, Test Loss: 0.0300
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0400, Test Loss: 0.0303
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0405, Test Loss: 0.0301
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0398, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0398, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0393, Test Loss: 0.0298
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0394, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0386, Test Loss: 0.0299
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0388, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0392, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0389, Test Loss: 0.0297
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0392, Test Loss: 0.0295
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0386, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0391, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0388, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0387, Test Loss: 0.0296
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
# Normalized Feature Phi range: -0.9987468179464775 to 1.0
# Normalized Feature Theta range: 0.004026122250999709 to 0.9932257217575585
# Normalized Target Phi range: -0.9996426482636093 to 0.9999915158988666
# Normalized Target Theta range: 0.008747641666239578 to 0.9978211921309839
#
# Experimenting with model size: small (d_model=16, n_layers=1, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 1.5016, Test Loss: 0.6602
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.3759, Test Loss: 0.2426
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.2137, Test Loss: 0.1555
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.1765, Test Loss: 0.1239
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.1594, Test Loss: 0.1096
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.1480, Test Loss: 0.0985
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.1390, Test Loss: 0.0918
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.1308, Test Loss: 0.0838
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.1228, Test Loss: 0.0806
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.1163, Test Loss: 0.0740
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.1104, Test Loss: 0.0703
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.1055, Test Loss: 0.0677
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.1010, Test Loss: 0.0641
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0979, Test Loss: 0.0627
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0949, Test Loss: 0.0626
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0920, Test Loss: 0.0612
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0897, Test Loss: 0.0591
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0876, Test Loss: 0.0566
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0853, Test Loss: 0.0545
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0838, Test Loss: 0.0520
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0819, Test Loss: 0.0529
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0802, Test Loss: 0.0496
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0790, Test Loss: 0.0491
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0776, Test Loss: 0.0479
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0770, Test Loss: 0.0474
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0757, Test Loss: 0.0474
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0743, Test Loss: 0.0467
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0736, Test Loss: 0.0459
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0734, Test Loss: 0.0458
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0723, Test Loss: 0.0447
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0718, Test Loss: 0.0451
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0711, Test Loss: 0.0451
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0709, Test Loss: 0.0444
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0702, Test Loss: 0.0437
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0699, Test Loss: 0.0439
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0695, Test Loss: 0.0438
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0696, Test Loss: 0.0434
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0688, Test Loss: 0.0437
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0691, Test Loss: 0.0438
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0688, Test Loss: 0.0435
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0687, Test Loss: 0.0433
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0686, Test Loss: 0.0434
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0685, Test Loss: 0.0430
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0683, Test Loss: 0.0430
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0685, Test Loss: 0.0433
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0686, Test Loss: 0.0432
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0683, Test Loss: 0.0432
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0682, Test Loss: 0.0431
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0682, Test Loss: 0.0431
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0683, Test Loss: 0.0431
#
# Experimenting with model size: medium (d_model=32, n_layers=2, n_heads=4)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 1.1928, Test Loss: 0.1594
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1552, Test Loss: 0.0909
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.1216, Test Loss: 0.0867
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.1042, Test Loss: 0.0872
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0934, Test Loss: 0.0840
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0860, Test Loss: 0.0793
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0811, Test Loss: 0.0656
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0778, Test Loss: 0.0596
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0746, Test Loss: 0.0567
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0727, Test Loss: 0.0535
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0704, Test Loss: 0.0514
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0686, Test Loss: 0.0548
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0663, Test Loss: 0.0522
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0646, Test Loss: 0.0494
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0627, Test Loss: 0.0466
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0617, Test Loss: 0.0481
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0599, Test Loss: 0.0454
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0585, Test Loss: 0.0440
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0573, Test Loss: 0.0458
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0553, Test Loss: 0.0461
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0550, Test Loss: 0.0432
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0533, Test Loss: 0.0422
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0527, Test Loss: 0.0402
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0512, Test Loss: 0.0409
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0506, Test Loss: 0.0426
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0497, Test Loss: 0.0399
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0490, Test Loss: 0.0406
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0481, Test Loss: 0.0419
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0469, Test Loss: 0.0390
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0467, Test Loss: 0.0405
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0464, Test Loss: 0.0390
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0462, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0453, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0449, Test Loss: 0.0382
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0446, Test Loss: 0.0390
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0444, Test Loss: 0.0393
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0440, Test Loss: 0.0387
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0438, Test Loss: 0.0390
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0434, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0430, Test Loss: 0.0391
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0434, Test Loss: 0.0389
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0426, Test Loss: 0.0388
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0426, Test Loss: 0.0392
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0427, Test Loss: 0.0384
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0421, Test Loss: 0.0385
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0430, Test Loss: 0.0385
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0426, Test Loss: 0.0384
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0428, Test Loss: 0.0385
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0426, Test Loss: 0.0384
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0426, Test Loss: 0.0384
#
# Experimenting with model size: large (d_model=64, n_layers=3, n_heads=8)
# Model device: cuda:0
# Batch x device: cuda:0
# Epoch 1/50, Train Loss: 0.4004, Test Loss: 0.1175
# Batch x device: cuda:0
# Epoch 2/50, Train Loss: 0.1217, Test Loss: 0.1040
# Batch x device: cuda:0
# Epoch 3/50, Train Loss: 0.0934, Test Loss: 0.0774
# Batch x device: cuda:0
# Epoch 4/50, Train Loss: 0.0834, Test Loss: 0.0668
# Batch x device: cuda:0
# Epoch 5/50, Train Loss: 0.0765, Test Loss: 0.0603
# Batch x device: cuda:0
# Epoch 6/50, Train Loss: 0.0704, Test Loss: 0.0493
# Batch x device: cuda:0
# Epoch 7/50, Train Loss: 0.0647, Test Loss: 0.0438
# Batch x device: cuda:0
# Epoch 8/50, Train Loss: 0.0600, Test Loss: 0.0420
# Batch x device: cuda:0
# Epoch 9/50, Train Loss: 0.0556, Test Loss: 0.0432
# Batch x device: cuda:0
# Epoch 10/50, Train Loss: 0.0517, Test Loss: 0.0419
# Batch x device: cuda:0
# Epoch 11/50, Train Loss: 0.0485, Test Loss: 0.0392
# Batch x device: cuda:0
# Epoch 12/50, Train Loss: 0.0448, Test Loss: 0.0396
# Batch x device: cuda:0
# Epoch 13/50, Train Loss: 0.0426, Test Loss: 0.0471
# Batch x device: cuda:0
# Epoch 14/50, Train Loss: 0.0393, Test Loss: 0.0421
# Batch x device: cuda:0
# Epoch 15/50, Train Loss: 0.0376, Test Loss: 0.0363
# Batch x device: cuda:0
# Epoch 16/50, Train Loss: 0.0355, Test Loss: 0.0347
# Batch x device: cuda:0
# Epoch 17/50, Train Loss: 0.0336, Test Loss: 0.0375
# Batch x device: cuda:0
# Epoch 18/50, Train Loss: 0.0314, Test Loss: 0.0389
# Batch x device: cuda:0
# Epoch 19/50, Train Loss: 0.0293, Test Loss: 0.0383
# Batch x device: cuda:0
# Epoch 20/50, Train Loss: 0.0286, Test Loss: 0.0332
# Batch x device: cuda:0
# Epoch 21/50, Train Loss: 0.0278, Test Loss: 0.0381
# Batch x device: cuda:0
# Epoch 22/50, Train Loss: 0.0262, Test Loss: 0.0330
# Batch x device: cuda:0
# Epoch 23/50, Train Loss: 0.0249, Test Loss: 0.0328
# Batch x device: cuda:0
# Epoch 24/50, Train Loss: 0.0247, Test Loss: 0.0329
# Batch x device: cuda:0
# Epoch 25/50, Train Loss: 0.0241, Test Loss: 0.0326
# Batch x device: cuda:0
# Epoch 26/50, Train Loss: 0.0229, Test Loss: 0.0347
# Batch x device: cuda:0
# Epoch 27/50, Train Loss: 0.0228, Test Loss: 0.0308
# Batch x device: cuda:0
# Epoch 28/50, Train Loss: 0.0222, Test Loss: 0.0327
# Batch x device: cuda:0
# Epoch 29/50, Train Loss: 0.0213, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 30/50, Train Loss: 0.0214, Test Loss: 0.0295
# Batch x device: cuda:0
# Epoch 31/50, Train Loss: 0.0210, Test Loss: 0.0320
# Batch x device: cuda:0
# Epoch 32/50, Train Loss: 0.0210, Test Loss: 0.0303
# Batch x device: cuda:0
# Epoch 33/50, Train Loss: 0.0202, Test Loss: 0.0306
# Batch x device: cuda:0
# Epoch 34/50, Train Loss: 0.0193, Test Loss: 0.0301
# Batch x device: cuda:0
# Epoch 35/50, Train Loss: 0.0202, Test Loss: 0.0311
# Batch x device: cuda:0
# Epoch 36/50, Train Loss: 0.0199, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 37/50, Train Loss: 0.0195, Test Loss: 0.0298
# Batch x device: cuda:0
# Epoch 38/50, Train Loss: 0.0193, Test Loss: 0.0285
# Batch x device: cuda:0
# Epoch 39/50, Train Loss: 0.0190, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 40/50, Train Loss: 0.0187, Test Loss: 0.0285
# Batch x device: cuda:0
# Epoch 41/50, Train Loss: 0.0193, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 42/50, Train Loss: 0.0189, Test Loss: 0.0287
# Batch x device: cuda:0
# Epoch 43/50, Train Loss: 0.0187, Test Loss: 0.0290
# Batch x device: cuda:0
# Epoch 44/50, Train Loss: 0.0193, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 45/50, Train Loss: 0.0186, Test Loss: 0.0296
# Batch x device: cuda:0
# Epoch 46/50, Train Loss: 0.0186, Test Loss: 0.0294
# Batch x device: cuda:0
# Epoch 47/50, Train Loss: 0.0192, Test Loss: 0.0292
# Batch x device: cuda:0
# Epoch 48/50, Train Loss: 0.0178, Test Loss: 0.0291
# Batch x device: cuda:0
# Epoch 49/50, Train Loss: 0.0180, Test Loss: 0.0292
# Batch x device: cuda:0
# Epoch 50/50, Train Loss: 0.0195, Test Loss: 0.0292

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda
